# %% [markdown]
# # CityBikes

# %% [markdown]
# Send a request to CityBikes for the city of your choice.

# %%
#Importing necessary packages

import requests
from IPython.display import JSON

#Making an API request to citybikes for all stations
city_bike_networks = requests.get("http://api.citybik.es/v2/networks").json()

city_bike_networks
# Out:
# {'networks': [{'company': ['ЗАО «СитиБайк»'],
#    'href': '/v2/networks/velobike-moscow',
#    'id': 'velobike-moscow',
#    'location': {'city': 'Moscow',
#     'country': 'RU',
#     'latitude': 55.75,
#     'longitude': 37.616667},
#    'name': 'Velobike'},
#   {'company': ['Urban Infrastructure Partner'],
#    'href': '/v2/networks/baerum-bysykkel',
#    'id': 'baerum-bysykkel',
#    'location': {'city': 'Bærum',
#     'country': 'NO',
#     'latitude': 59.89455,
#     'longitude': 10.546343},
#    'name': 'Bysykkel'},
#   {'company': ['Comunicare S.r.l.'],
#    'href': '/v2/networks/bicincitta-siena',
#    'id': 'bicincitta-siena',
#    'location': {'city': 'Siena',
#     'country': 'IT',
#     'latitude': 43.3186,
#     'longitude': 11.3306},
#    'name': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=202'},
#   {'company': ['Cyclopolis Systems'],
#    'href': '/v2/networks/cyclopolis-maroussi',
#    'id': 'cyclopolis-maroussi',
# ...

# %%
#Making a request for stations located in Toronto
network_id = 'bixi-toronto'
network_json = requests.get("http://api.citybik.es/v2/networks/"+network_id).json()
network_json['network']['stations']
# Out:
# [{'empty_slots': 5,
#   'extra': {'address': 'Queen St E / Woodward Ave',
#    'altitude': 0.0,
#    'ebikes': 0,
#    'has_ebikes': True,
#    'last_updated': 1695625744,
#    'normal_bikes': 14,
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'rental_uris': {},
#    'renting': 1,
#    'returning': 1,
#    'slots': 19,
#    'uid': '7303'},
#   'free_bikes': 14,
#   'id': 'fb337bbed72e2be090071e199899b2be',
#   'latitude': 43.665269,
#   'longitude': -79.319796,
#   'name': 'Queen St E / Woodward Ave',
#   'timestamp': '2023-09-25T07:12:26.863000Z'},
#  {'empty_slots': 13,
#   'extra': {'address': 'Primrose Ave / Davenport Rd',
#    'altitude': 0.0,
#    'ebikes': 1,
#    'has_ebikes': True,
#    'last_updated': 1695625884,
#    'normal_bikes': 1,
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'rental_uris': {},
#    'renting': 1,
#    'returning': 1,
#    'slots': 15,
# ...

# %% [markdown]
# Parse through the response to get the details you want for the bike stations in that city (latitude, longitude, number of bikes).

# %%
#Parsing through the JSON response to get details
addresses = [station['name'] for station in network_json['network']['stations']]
latitude = [station['latitude'] for station in network_json['network']['stations']]
longitude = [station['longitude'] for station in network_json['network']['stations']]
free_bikes = [station['free_bikes'] for station in network_json['network']['stations']]

# %% [markdown]
# Put your parsed results into a DataFrame.

# %%
import pandas as pd

# %%
#Creating dataframe to store the response
df = pd.DataFrame({
              'station_address' : addresses,
              'latitude' : latitude,
              'longitude' : longitude,
              'free_bikes' : free_bikes
             
             })

# %%
df
# Out:
#                        station_address   latitude  longitude  free_bikes
# 0            Queen St E / Woodward Ave  43.665269 -79.319796          14
# 1          Primrose Ave / Davenport Rd  43.671420 -79.445947           2
# 2            Queen St. E / Rhodes Ave.  43.666224 -79.317693          13
# 3                 Bond St / Queen St E  43.653236 -79.376716           7
# 4             Church St / Alexander St  43.663722 -79.380288          10
# ..                                 ...        ...        ...         ...
# 700  Victoria Park Ave / Edge Park Ave  43.717679 -79.299616           4
# 701   Galbraith Rd / King's College Rd  43.660387 -79.395378           1
# 702              Exhibition GO Station  43.635201 -79.418771           1
# 703          Princes Gate / Nunavut Dr  43.633352 -79.414363           2
# 704                       800 Fleet St  43.636804 -79.408832          31
#
# [705 rows x 4 columns]

# %%
#Dropping rows for ease of use for further parts of the project and simplicity
df = df.drop(df.index[50:706])
df
# Out:
#                                 station_address   latitude  longitude  \
# 0                     Queen St E / Woodward Ave  43.665269 -79.319796
# 1                   Primrose Ave / Davenport Rd  43.671420 -79.445947
# 2                     Queen St. E / Rhodes Ave.  43.666224 -79.317693
# 3                          Bond St / Queen St E  43.653236 -79.376716
# 4                      Church St / Alexander St  43.663722 -79.380288
# 5     University Ave / Gerrard St W (East Side)  43.657763 -79.389165
# 6                          Edward St / Yonge St  43.656729 -79.382736
# 7                       Euclid Ave / Bloor St W  43.664467 -79.414783
# 8                         Yonge St / Aylmer Ave  43.675492 -79.388858
# 9                      Davenport Rd / Avenue Rd  43.674991 -79.396273
# 10                     Yonge St / Yorkville Ave  43.671944 -79.387778
# 11                  Dundas St E / Broadview Ave  43.662365 -79.351104
# ...

# %%
#Adding an ID column for joining tables further on
df['ID'] = df.index +1

# %%
df
# Out:
#                                 station_address   latitude  longitude  \
# 0                     Queen St E / Woodward Ave  43.665269 -79.319796
# 1                   Primrose Ave / Davenport Rd  43.671420 -79.445947
# 2                     Queen St. E / Rhodes Ave.  43.666224 -79.317693
# 3                          Bond St / Queen St E  43.653236 -79.376716
# 4                      Church St / Alexander St  43.663722 -79.380288
# 5     University Ave / Gerrard St W (East Side)  43.657763 -79.389165
# 6                          Edward St / Yonge St  43.656729 -79.382736
# 7                       Euclid Ave / Bloor St W  43.664467 -79.414783
# 8                         Yonge St / Aylmer Ave  43.675492 -79.388858
# 9                      Davenport Rd / Avenue Rd  43.674991 -79.396273
# 10                     Yonge St / Yorkville Ave  43.671944 -79.387778
# 11                  Dundas St E / Broadview Ave  43.662365 -79.351104
# ...

# %%
#Converting dataframe into a csv file
df.to_csv('city_bikes.csv', index=False)
