# %% [markdown]
# Join the data from Part 1 with the data from Part 2 to create a new dataframe.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
import seaborn as sns

# %%
#Loading city bikes csv file
df_city_bikes = pd.read_csv('city_bikes.csv')

# %%
df_city_bikes
# Out:
#                                 station_address   latitude  longitude  \
# 0                     Queen St E / Woodward Ave  43.665269 -79.319796
# 1                   Primrose Ave / Davenport Rd  43.671420 -79.445947
# 2                     Queen St. E / Rhodes Ave.  43.666224 -79.317693
# 3                          Bond St / Queen St E  43.653236 -79.376716
# 4                      Church St / Alexander St  43.663722 -79.380288
# 5     University Ave / Gerrard St W (East Side)  43.657763 -79.389165
# 6                          Edward St / Yonge St  43.656729 -79.382736
# 7                       Euclid Ave / Bloor St W  43.664467 -79.414783
# 8                         Yonge St / Aylmer Ave  43.675492 -79.388858
# 9                      Davenport Rd / Avenue Rd  43.674991 -79.396273
# 10                     Yonge St / Yorkville Ave  43.671944 -79.387778
# 11                  Dundas St E / Broadview Ave  43.662365 -79.351104
# 12  Front St W / Yonge St (Hockey Hall of Fame)  43.646144 -79.377962
# 13                      Gerrard St E / River St  43.663993 -79.358534
# 14                      Jarvis St / Dundas St E  43.657266 -79.374756
# 15                      Logan Av / Gerrard St E  43.667214 -79.345270
# 16                       Regal Rd / Dufferin St  43.673939 -79.441159
# 17                       Morse St / Eastern Ave  43.657991 -79.340075
# 18     Alton Ave / Dundas St E (Greenwood Park)  43.667450 -79.329408
# 19                      Blake St / Boultbee Ave  43.672453 -79.338259
# 20                  Eastern Ave / Winnifred Ave  43.659209 -79.334840
# 21                   Gamble Ave / Broadview Ave  43.689211 -79.354380
# 22  111 Bond St (North of Dundas St E)  - SMART  43.656927 -79.378497
# 23            Dundas St E / Pembroke St - SMART  43.658295 -79.372346
# 24         Victoria Park Subway Station - SMART  43.694015 -79.288984
# 25            Wychwood Ave / Benson Ave - SMART  43.680916 -79.422968
# 26                       Lawton Blvd / Yonge St  43.691067 -79.395350
# 27                    Yonge St / Davisville Ave  43.697597 -79.396540
# 28                 Fort York  Blvd / Capreol Ct  43.639832 -79.395954
# 29                   St. George St / Bloor St W  43.667333 -79.399429
# 30                          King St W / York St  43.648001 -79.383177
# 31                      University Ave / Elm St  43.656518 -79.389099
# 32             Rosehill Ave / Avoca Ave - SMART  43.687999 -79.389060
# 33                     Bloor St W / Dundas St W  43.656389 -79.451667
# 34                 Bathurst St / Fort York Blvd  43.639179 -79.399595
# 35                   Spadina Ave / Willcocks St  43.661667 -79.401389
# 36                 Cariboo Ave / Railpath Trail  43.666667 -79.458333
# 37                       Dundas St W / Edna Ave  43.657192 -79.452559
# 38                        College St / Major St  43.657600 -79.403200
# 39                        McGill St / Church St  43.660694 -79.379052
# 40               Queens Quay W / Dan Leckie Way  43.636533 -79.395854
# 41                           College Park South  43.659777 -79.382767
# 42             25 York St – Union Station South  43.643667 -79.380414
# 43         161 Bleecker St (South of Wellesley)  43.666233 -79.373327
# 44                 Spadina Ave / Fort York Blvd  43.640114 -79.393249
# 45                     Augusta Ave / Denison Sq  43.653766 -79.401676
# 46                  Lansdowne Ave / Whytock Ave  43.653889 -79.441389
# 47                    Sterling Rd / Dundas St W  43.650833 -79.443056
# 48                  St Clarens Ave / College St  43.651238 -79.438680
# 49                   Ossington Ave / College St  43.654491 -79.422634
#
#     free_bikes  ID
# 0           14   1
# 1            2   2
# 2           13   3
# 3            7   4
# 4           10   5
# 5            0   6
# 6           11   7
# 7            9   8
# 8           13   9
# 9            3  10
# 10           1  11
# 11          15  12
# 12           6  13
# 13           8  14
# 14          13  15
# 15          14  16
# 16           1  17
# 17           5  18
# 18          13  19
# 19          10  20
# 20           9  21
# 21           7  22
# 22           7  23
# 23          14  24
# 24           6  25
# 25           7  26
# 26          13  27
# 27           1  28
# 28          26  29
# 29           0  30
# 30          22  31
# 31           6  32
# 32           3  33
# 33           1  34
# 34          11  35
# 35           0  36
# 36           2  37
# 37           1  38
# 38           7  39
# 39          10  40
# 40          23  41
# 41           9  42
# 42           7  43
# 43           8  44
# 44          15  45
# 45           6  46
# 46           2  47
# 47           0  48
# 48           1  49
# 49           2  50

# %%
#Loading foursquare results csv file
df = pd.read_csv('foursquare_results.csv')

# %%
df
# Out:
#      ID                  place_name  rating      place_address
# 0     1  Leslieville Farmers Market     9.1  150 Greenwood Ave
# 1     1           Rorschach Brewing     8.7   1001 Eastern Ave
# 2     1                 Chick-N-Joy     7.5    1483 Queen St E
# 3     1                   Velotique     7.8    1592 Queen St E
# 4     1                     O Sushi     7.5      6 Coxwell Ave
# ..   ..                         ...     ...                ...
# 495  50                    YamChops     8.4     705 College St
# 496  50                   Giulietta     8.4     972 College St
# 497  50                    Terrazza     8.3     372 Harbord St
# 498  50                     Hanmoto     8.9     2 Lakeview Ave
# 499  50        Communist's Daughter     8.4   1149 Dundas St W
#
# [500 rows x 4 columns]

# %%
#Loading yelp results csv file
df_2 = pd.read_csv('yelp_results.csv')

# %%
df_2
# Out:
#      ID                    place_name  rating          place_address
# 0     1                       O Sushi     4.0       6 Coxwell Avenue
# 1     1                     Lake Inez     4.5  1471 Gerrard Street E
# 2     1           The Burger's Priest     3.5    1636 Queen Street E
# 3     1                      Jaclyn's     4.5    1588 Queen Street E
# 4     1              Burrito Bandidos     3.5    1614 Queen Street E
# ..   ..                           ...     ...                    ...
# 995  50               The Night Baker     4.0     825 College Street
# 996  50  The Daily Dumpling Wonton Co     4.0         792 College St
# 997  50                     Taverniti     4.0     591 College Street
# 998  50              La Bella Managua     4.5     872 Bloor Street W
# 999  50     Imanishi Japanese Kitchen     4.0   1330 Dundas Street W
#
# [1000 rows x 4 columns]

# %%
#Joining yelp results table and city bikes table together
merged_tables = pd.merge(df_city_bikes, df_2, on='ID')

# %%
merged_tables
# Out:
#                 station_address   latitude  longitude  free_bikes  ID  \
# 0     Queen St E / Woodward Ave  43.665269 -79.319796          14   1
# 1     Queen St E / Woodward Ave  43.665269 -79.319796          14   1
# 2     Queen St E / Woodward Ave  43.665269 -79.319796          14   1
# 3     Queen St E / Woodward Ave  43.665269 -79.319796          14   1
# 4     Queen St E / Woodward Ave  43.665269 -79.319796          14   1
# ..                          ...        ...        ...         ...  ..
# 995  Ossington Ave / College St  43.654491 -79.422634           2  50
# 996  Ossington Ave / College St  43.654491 -79.422634           2  50
# 997  Ossington Ave / College St  43.654491 -79.422634           2  50
# 998  Ossington Ave / College St  43.654491 -79.422634           2  50
# 999  Ossington Ave / College St  43.654491 -79.422634           2  50
#
#                        place_name  rating          place_address  result_ID
# 0                         O Sushi     4.0       6 Coxwell Avenue          1
# 1                       Lake Inez     4.5  1471 Gerrard Street E          2
# 2             The Burger's Priest     3.5    1636 Queen Street E          3
# 3                        Jaclyn's     4.5    1588 Queen Street E          4
# 4                Burrito Bandidos     3.5    1614 Queen Street E          5
# ..                            ...     ...                    ...        ...
# 995               The Night Baker     4.0     825 College Street        996
# 996  The Daily Dumpling Wonton Co     4.0         792 College St        997
# 997                     Taverniti     4.0     591 College Street        998
# 998              La Bella Managua     4.5     872 Bloor Street W        999
# 999     Imanishi Japanese Kitchen     4.0   1330 Dundas Street W       1000
#
# [1000 rows x 9 columns]

# %%
#Creating a primary key for the merged tables
merged_tables['result_ID'] = merged_tables.index +1

# %% [markdown]
# Provide a visualization that you used as part of your EDA process. Explain the initial pattern or relationship you discoved through this visualization.

# %%
merged_tables.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   station_address  1000 non-null   object
#  1   latitude         1000 non-null   float64
#  2   longitude        1000 non-null   float64
#  3   free_bikes       1000 non-null   int64
#  4   ID               1000 non-null   int64
#  5   place_name       1000 non-null   object
#  6   rating           1000 non-null   float64
#  7   place_address    1000 non-null   object
#  8   result_ID        1000 non-null   int64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 70.4+ KB

# %%
merged_tables.describe()
# Out:
#           latitude    longitude   free_bikes           ID       rating  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     43.662538   -79.387520     7.880000    25.500000     4.057500
# std       0.013810     0.037164     6.140302    14.438091     0.377606
# min      43.636533   -79.458333     0.000000     1.000000     2.500000
# 25%      43.654491   -79.401676     2.000000    13.000000     4.000000
# 50%      43.660235   -79.388959     7.000000    25.500000     4.000000
# 75%      43.667450   -79.373327    13.000000    38.000000     4.500000
# max      43.697597   -79.288984    26.000000    50.000000     5.000000
#
#          result_ID
# count  1000.000000
# mean    500.500000
# std     288.819436
# min       1.000000
# 25%     250.750000
# 50%     500.500000
# 75%     750.250000
# max    1000.000000

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].boxplot(merged_tables['rating'])
axes[1].boxplot(merged_tables['rating'], whis=0.5)

plt.show()

# %%
sns.pairplot(merged_tables[['rating', 'free_bikes']])
plt.show()
# Out:
# C:\Users\got1p\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Database

# %% [markdown]
# Put all your results in an SQLite3 database (remember, SQLite stores its databases as files in your local machine - make sure to create your database in your project's data/ directory!)

# %%
#Creating connection for SQLite database

import sqlite3
from sqlite3 import Error

def create_connection(path):
    connection = None
    try:
        connection = sqlite3.connect(r"C:\Users\got1p\SMWP-Final-Project\Statistical-Modeling-Proj\data\merged_tables1.sqlite")
        print("Connection to SQLite DB successful")
    except Error as e:
        print(f"The error '{e}' occurred")

    return connection

# %%
connection = create_connection("merged_tables1.sqlite")
# Out:
# Connection to SQLite DB successful

# %%
#Creating function for executing queries
def execute_query(connection, query):
    cursor = connection.cursor()
    try:
        cursor.execute(query)
        connection.commit()
        print("Query executed successfully")
    except Error as e:
        print(f"The error '{e}' occurred")

# %%
#Creating table to store data
create_data_table = """
CREATE TABLE IF NOT EXISTS data (
  result_ID INTEGER PRIMARY KEY,
  station_address TEXT,
  latitude REAL,
  longitude REAL,
  free_bikes INTEGER,
  ID INTEGER,
  place_name TEXT,
  rating INTEGER,
  place_address TEXT,
  
  
);
"""

# %%
#Inserting table values into SQLite database
merged_tables.to_sql('data', connection, index=False)
# Out:
# 1000

# %%
#Creating function for reading SQL queries
def execute_read_query(connection, query):
    cursor = connection.cursor()
    result = None
    try:
        cursor.execute(query)
        result = cursor.fetchall()
        return result
    except Error as e:
        print(f"The error '{e}' occurred")

# %%
#Selecting data from database
select_data = "SELECT * from data"
data = execute_read_query(connection, select_data)

data
# Out:
# [('Queen St E / Woodward Ave',
#   43.665269,
#   -79.319796,
#   14,
#   1,
#   'O Sushi',
#   4.0,
#   '6 Coxwell Avenue',
#   1),
#  ('Queen St E / Woodward Ave',
#   43.665269,
#   -79.319796,
#   14,
#   1,
#   'Lake Inez',
#   4.5,
#   '1471 Gerrard Street E',
#   2),
#  ('Queen St E / Woodward Ave',
#   43.665269,
#   -79.319796,
#   14,
#   1,
#   "The Burger's Priest",
#   3.5,
#   '1636 Queen Street E',
#   3),
#  ('Queen St E / Woodward Ave',
#   43.665269,
#   -79.319796,
#   14,
#   1,
#   "Jaclyn's",
#   4.5,
#   '1588 Queen Street E',
#   4),
#  ('Queen St E / Woodward Ave',
#   43.665269,
#   -79.319796,
#   14,
#   1,
#   'Burrito Bandidos',
#   3.5,
#   '1614 Queen Street E',
#   5),
#  ('Queen St E / Woodward Ave',
#   43.665269,
#   -79.319796,
#   14,
#   1,
#   'Casa Di Giorgios',
#   4.0,
#   '1646 Queen St E',
#   6),
#  ('Queen St E / Woodward Ave',
#   43.665269,
#   -79.319796,
#   14,
#   1,
#   "Maha's",
#   4.0,
#   '226 Greenwood Avenue',
#   7),
#  ('Queen St E / Woodward Ave',
#   43.665269,
#   -79.319796,
#   14,
#   1,
#   "McDonald's",
#   2.5,
#   '29-31 Woodward Avenue',
#   8),
#  ('Queen St E / Woodward Ave',
#   43.665269,
#   -79.319796,
#   14,
#   1,
#   'Lahore Tikka House',
#   3.5,
#   '1365 Gerrard Street E',
#   9),
#  ('Queen St E / Woodward Ave',
#   43.665269,
#   -79.319796,
#   14,
#   1,
#   'Leslie Jones',
#   4.0,
#   '1182 Queen Street E',
#   10),
#  ('Queen St E / Woodward Ave',
#   43.665269,
#   -79.319796,
#   14,
#   1,
#   'Tea N Bannock',
#   4.5,
#   '1294 Gerrard Street E',
#   11),
#  ('Queen St E / Woodward Ave',
#   43.665269,
#   -79.319796,
#   14,
#   1,
#   'The Sidekick',
#   4.5,
#   '1374 Queen Street E',
#   12),
#  ('Queen St E / Woodward Ave',
#   43.665269,
#   -79.319796,
#   14,
#   1,
#   "Eulalie's Corner Store",
#   4.5,
#   '1438 Gerrard Street E',
#   13),
#  ('Queen St E / Woodward Ave',
#   43.665269,
#   -79.319796,
#   14,
#   1,
#   'Yaya Greek Bistro',
#   4.0,
#   '1186 Queen Street E',
#   14),
#  ('Queen St E / Woodward Ave',
#   43.665269,
#   -79.319796,
#   14,
#   1,
#   "Lazy Daisy's Cafe",
#   4.0,
#   '1515 Gerrard Street E',
#   15),
#  ('Queen St E / Woodward Ave',
#   43.665269,
#   -79.319796,
#   14,
#   1,
#   "Gio Rana's Really Really Nice Restaurant",
#   4.0,
#   '1220 Queen Street East',
#   16),
#  ('Queen St E / Woodward Ave',
#   43.665269,
#   -79.319796,
#   14,
#   1,
#   'Nodo Leslieville',
#   4.0,
#   '1192 Queen Street East',
#   17),
#  ('Queen St E / Woodward Ave',
#   43.665269,
#   -79.319796,
#   14,
#   1,
#   'Chick-N-Joy',
#   4.0,
#   '1483 Queen Street E',
#   18),
#  ('Queen St E / Woodward Ave',
#   43.665269,
#   -79.319796,
#   14,
#   1,
#   'Udupi Palace',
#   3.5,
#   '1460 Gerrard Street E',
#   19),
#  ('Queen St E / Woodward Ave',
#   43.665269,
#   -79.319796,
#   14,
#   1,
#   'Regency Restaurant',
#   4.0,
#   '1423 Gerrard Street E',
#   20),
#  ('Primrose Ave / Davenport Rd',
#   43.67142,
#   -79.445947,
#   2,
#   2,
#   'Agio',
#   4.5,
#   '1351 St Clair Avenue W',
#   21),
#  ('Primrose Ave / Davenport Rd',
#   43.67142,
#   -79.445947,
#   2,
#   2,
#   'Rush Hour',
#   4.5,
#   '1438A Dufferin Street',
#   22),
#  ('Primrose Ave / Davenport Rd',
#   43.67142,
#   -79.445947,
#   2,
#   2,
#   'Love Chix',
#   4.0,
#   '33 Powerhouse Street',
#   23),
#  ('Primrose Ave / Davenport Rd',
#   43.67142,
#   -79.445947,
#   2,
#   2,
#   'CANO Restaurant',
#   4.5,
#   '1108 St Clair Avenue W',
#   24),
#  ('Primrose Ave / Davenport Rd',
#   43.67142,
#   -79.445947,
#   2,
#   2,
#   'Barista & Chef',
#   4.5,
#   '1006 Saint Clair Avenue W',
#   25),
#  ('Primrose Ave / Davenport Rd',
#   43.67142,
#   -79.445947,
#   2,
#   2,
#   'Famiglia Baldassarre',
#   4.5,
#   '122 Geary Avenue',
#   26),
#  ('Primrose Ave / Davenport Rd',
#   43.67142,
#   -79.445947,
#   2,
#   2,
#   'Tre Mari Bakery',
#   4.5,
#   '1311 Saint Clair Avenue W',
#   27),
#  ('Primrose Ave / Davenport Rd',
#   43.67142,
#   -79.445947,
#   2,
#   2,
#   'Pizza e Pazzi',
#   4.0,
#   '1182 St Clair Avenue W',
#   28),
#  ('Primrose Ave / Davenport Rd',
#   43.67142,
#   -79.445947,
#   2,
#   2,
#   'Rio 40 Restaurant',
#   4.0,
#   '1256 Saint Clair Avenue West',
#   29),
#  ('Primrose Ave / Davenport Rd',
#   43.67142,
#   -79.445947,
#   2,
#   2,
#   'Marcello’s pizzeria',
#   4.0,
#   '1163 Saint Clair Avenue W',
#   30),
#  ('Primrose Ave / Davenport Rd',
#   43.67142,
#   -79.445947,
#   2,
#   2,
#   'Good Behaviour',
#   4.5,
#   '342 Westmoreland Avenue N',
#   31),
#  ('Primrose Ave / Davenport Rd',
#   43.67142,
#   -79.445947,
#   2,
#   2,
#   'Tuckshop Kitchen',
#   4.5,
#   '1640 Dupont Street',
#   32),
#  ('Primrose Ave / Davenport Rd',
#   43.67142,
#   -79.445947,
#   2,
#   2,
#   'Parallel',
#   4.0,
#   '217 Geary Avenue',
#   33),
#  ('Primrose Ave / Davenport Rd',
#   43.67142,
#   -79.445947,
#   2,
#   2,
#   'The Sovereign',
#   4.5,
#   '1359 Davenport Road',
#   34),
#  ('Primrose Ave / Davenport Rd',
#   43.67142,
#   -79.445947,
#   2,
#   2,
#   'Atomic 10',
#   4.5,
#   '145 Lauder Ave',
#   35),
#  ('Primrose Ave / Davenport Rd',
#   43.67142,
#   -79.445947,
#   2,
#   2,
#   'Khmer Thai Restaurant',
#   4.0,
#   '1018 St Clair Avenue W',
#   36),
#  ('Primrose Ave / Davenport Rd',
#   43.67142,
#   -79.445947,
#   2,
#   2,
#   'DeSotos Eatery',
#   4.0,
#   '1079 St Clair Avenue West',
#   37),
#  ('Primrose Ave / Davenport Rd',
#   43.67142,
#   -79.445947,
#   2,
#   2,
#   "King's Tacos",
#   4.0,
#   '1190 St Clair Avenue W',
#   38),
#  ('Primrose Ave / Davenport Rd',
#   43.67142,
#   -79.445947,
#   2,
#   2,
#   'The Greater Good Bar',
#   4.0,
#   '229 Geary Avenue',
#   39),
#  ('Primrose Ave / Davenport Rd',
#   43.67142,
#   -79.445947,
#   2,
#   2,
#   'Frank’s Pizza House',
#   3.5,
#   '1352 St Clair Avenue W',
#   40),
#  ('Queen St. E / Rhodes Ave.',
#   43.666224,
#   -79.317693,
#   13,
#   3,
#   'Casa Di Giorgios',
#   4.0,
#   '1646 Queen St E',
#   41),
#  ('Queen St. E / Rhodes Ave.',
#   43.666224,
#   -79.317693,
#   13,
#   3,
#   'O Sushi',
#   4.0,
#   '6 Coxwell Avenue',
#   42),
#  ('Queen St. E / Rhodes Ave.',
#   43.666224,
#   -79.317693,
#   13,
#   3,
#   "The Burger's Priest",
#   3.5,
#   '1636 Queen Street E',
#   43),
#  ('Queen St. E / Rhodes Ave.',
#   43.666224,
#   -79.317693,
#   13,
#   3,
#   'Burrito Bandidos',
#   3.5,
#   '1614 Queen Street E',
#   44),
#  ('Queen St. E / Rhodes Ave.',
#   43.666224,
#   -79.317693,
#   13,
#   3,
#   "Jaclyn's",
#   4.5,
#   '1588 Queen Street E',
#   45),
#  ('Queen St. E / Rhodes Ave.',
#   43.666224,
#   -79.317693,
#   13,
#   3,
#   'Lake Inez',
#   4.5,
#   '1471 Gerrard Street E',
#   46),
#  ('Queen St. E / Rhodes Ave.',
#   43.666224,
#   -79.317693,
#   13,
#   3,
#   "Maha's",
#   4.0,
#   '226 Greenwood Avenue',
#   47),
#  ('Queen St. E / Rhodes Ave.',
#   43.666224,
#   -79.317693,
#   13,
#   3,
#   'Lahore Tikka House',
#   3.5,
#   '1365 Gerrard Street E',
#   48),
#  ('Queen St. E / Rhodes Ave.',
#   43.666224,
#   -79.317693,
#   13,
#   3,
#   'Tea N Bannock',
#   4.5,
#   '1294 Gerrard Street E',
#   49),
#  ('Queen St. E / Rhodes Ave.',
#   43.666224,
#   -79.317693,
#   13,
#   3,
#   "Eulalie's Corner Store",
#   4.5,
#   '1438 Gerrard Street E',
#   50),
#  ('Queen St. E / Rhodes Ave.',
#   43.666224,
#   -79.317693,
#   13,
#   3,
#   "Lazy Daisy's Cafe",
#   4.0,
#   '1515 Gerrard Street E',
#   51),
#  ('Queen St. E / Rhodes Ave.',
#   43.666224,
#   -79.317693,
#   13,
#   3,
#   'Sauvignon Bistro',
#   4.0,
#   '1862 Queen Street E',
#   52),
#  ('Queen St. E / Rhodes Ave.',
#   43.666224,
#   -79.317693,
#   13,
#   3,
#   'Udupi Palace',
#   3.5,
#   '1460 Gerrard Street E',
#   53),
#  ('Queen St. E / Rhodes Ave.',
#   43.666224,
#   -79.317693,
#   13,
#   3,
#   "McDonald's",
#   2.5,
#   '29-31 Woodward Avenue',
#   54),
#  ('Queen St. E / Rhodes Ave.',
#   43.666224,
#   -79.317693,
#   13,
#   3,
#   'The Sidekick',
#   4.5,
#   '1374 Queen Street E',
#   55),
#  ('Queen St. E / Rhodes Ave.',
#   43.666224,
#   -79.317693,
#   13,
#   3,
#   'Regency Restaurant',
#   4.0,
#   '1423 Gerrard Street E',
#   56),
#  ('Queen St. E / Rhodes Ave.',
#   43.666224,
#   -79.317693,
#   13,
#   3,
#   'Le Conciliabule',
#   4.5,
#   '1300 Gerrard Street E',
#   57),
#  ('Queen St. E / Rhodes Ave.',
#   43.666224,
#   -79.317693,
#   13,
#   3,
#   'Butter Chicken Roti',
#   2.5,
#   '1610 Queen Street E',
#   58),
#  ('Queen St. E / Rhodes Ave.',
#   43.666224,
#   -79.317693,
#   13,
#   3,
#   'British Style Fish & Chips',
#   4.0,
#   '73 Coxwell Avenue',
#   59),
#  ('Queen St. E / Rhodes Ave.',
#   43.666224,
#   -79.317693,
#   13,
#   3,
#   'Jules Bistro',
#   3.5,
#   '1290 Queen St E',
#   60),
#  ('Bond St / Queen St E',
#   43.653236,
#   -79.376716,
#   7,
#   4,
#   'Richmond Station',
#   4.5,
#   '1 Richmond Street W',
#   61),
#  ('Bond St / Queen St E',
#   43.653236,
#   -79.376716,
#   7,
#   4,
#   'George Restaurant',
#   4.5,
#   '111 Queen Street E',
#   62),
#  ('Bond St / Queen St E',
#   43.653236,
#   -79.376716,
#   7,
#   4,
#   'The Carbon Bar',
#   4.0,
#   '99 Queen Street East',
#   63),
#  ('Bond St / Queen St E',
#   43.653236,
#   -79.376716,
#   7,
#   4,
#   'Terroni',
#   3.5,
#   '57A Adelaide Street E',
#   64),
#  ('Bond St / Queen St E',
#   43.653236,
#   -79.376716,
#   7,
#   4,
#   'Pearl Diver',
#   4.0,
#   '100 Adelaide Street E',
#   65),
#  ('Bond St / Queen St E',
#   43.653236,
#   -79.376716,
#   7,
#   4,
#   'Beerbistro',
#   4.0,
#   '18 King Street E',
#   66),
#  ('Bond St / Queen St E',
#   43.653236,
#   -79.376716,
#   7,
#   4,
#   'Pai Northern Thai Kitchen',
#   4.5,
#   '18 Duncan Street',
#   67),
#  ('Bond St / Queen St E',
#   43.653236,
#   -79.376716,
#   7,
#   4,
#   'Carisma',
#   4.0,
#   '15 Toronto Street',
#   68),
#  ('Bond St / Queen St E',
#   43.653236,
#   -79.376716,
#   7,
#   4,
#   'Hendriks Restaurant & Bar',
#   4.0,
#   '218 Yonge Street',
#   69),
#  ('Bond St / Queen St E',
#   43.653236,
#   -79.376716,
#   7,
#   4,
#   'Byblos',
#   4.5,
#   '11 Duncan Street',
#   70),
#  ('Bond St / Queen St E',
#   43.653236,
#   -79.376716,
#   7,
#   4,
#   'Cafe Oro Di Napoli',
#   4.5,
#   '75 Jarvis Street',
#   71),
#  ('Bond St / Queen St E',
#   43.653236,
#   -79.376716,
#   7,
#   4,
#   'Hokkaido Ramen Santouka',
#   4.0,
#   '91 Dundas Street E',
#   72),
#  ('Bond St / Queen St E',
#   43.653236,
#   -79.376716,
#   7,
#   4,
#   'The Chase',
#   3.5,
#   '10 Temperance Street',
#   73),
#  ('Bond St / Queen St E',
#   43.653236,
#   -79.376716,
#   7,
#   4,
#   'Nami Restaurant',
#   3.5,
#   '55 Adelaide Street East',
#   74),
#  ('Bond St / Queen St E',
#   43.653236,
#   -79.376716,
#   7,
#   4,
#   'Gyu-Kaku Japanese BBQ',
#   4.0,
#   '81 Church Street',
#   75),
#  ('Bond St / Queen St E',
#   43.653236,
#   -79.376716,
#   7,
#   4,
#   'The Keg Steakhouse + Bar - York Street',
#   4.0,
#   '165 York Street',
#   76),
#  ('Bond St / Queen St E',
#   43.653236,
#   -79.376716,
#   7,
#   4,
#   'King Taps',
#   4.0,
#   '100 King Street W',
#   77),
#  ('Bond St / Queen St E',
#   43.653236,
#   -79.376716,
#   7,
#   4,
#   'Eggspectation',
#   4.0,
#   '483 Bay Street',
#   78),
#  ('Bond St / Queen St E',
#   43.653236,
#   -79.376716,
#   7,
#   4,
#   'Leña Restaurante',
#   3.5,
#   '176 Yonge Street',
#   79),
#  ('Bond St / Queen St E',
#   43.653236,
#   -79.376716,
#   7,
#   4,
#   'The Senator',
#   4.0,
#   '249 Victoria Street',
#   80),
#  ('Church St / Alexander St',
#   43.663722,
#   -79.380288,
#   10,
#   5,
#   'Kintaro Izakaya',
#   4.0,
#   '459 Church Street',
#   81),
#  ('Church St / Alexander St',
#   43.663722,
#   -79.380288,
#   10,
#   5,
#   'Hair of the Dog',
#   4.0,
#   '425 Church Street',
#   82),
#  ('Church St / Alexander St',
#   43.663722,
#   -79.380288,
#   10,
#   5,
#   'KINKA IZAKAYA ORIGINAL',
#   4.0,
#   '398 Church Street',
#   83),
#  ('Church St / Alexander St',
#   43.663722,
#   -79.380288,
#   10,
#   5,
#   'Si Lom Thai Bistro',
#   4.0,
#   '534 Church Street',
#   84),
#  ('Church St / Alexander St',
#   43.663722,
#   -79.380288,
#   10,
#   5,
#   'KINTON RAMEN',
#   4.0,
#   '396 Church Street',
#   85),
#  ('Church St / Alexander St',
#   43.663722,
#   -79.380288,
#   10,
#   5,
#   'The Keg Steakhouse + Bar',
#   4.0,
#   '515 Jarvis Street',
#   86),
#  ('Church St / Alexander St',
#   43.663722,
#   -79.380288,
#   10,
#   5,
#   'Storm Crow Manor',
#   4.0,
#   '580 Church Street',
#   87),
#  ('Church St / Alexander St',
#   43.663722,
#   -79.380288,
#   10,
#   5,
#   'Afuri',
#   4.0,
#   '411 Church Street',
#   88),
#  ('Church St / Alexander St',
#   43.663722,
#   -79.380288,
#   10,
#   5,
#   'Sambucas On Church',
#   3.5,
#   '489 Church Street',
#   89),
#  ('Church St / Alexander St',
#   43.663722,
#   -79.380288,
#   10,
#   5,
#   'Katsuya',
#   4.5,
#   '66 Gerrard Street E',
#   90),
#  ('Church St / Alexander St',
#   43.663722,
#   -79.380288,
#   10,
#   5,
#   'Kawa Sushi',
#   3.5,
#   '451 Church Street',
#   91),
#  ('Church St / Alexander St',
#   43.663722,
#   -79.380288,
#   10,
#   5,
#   'Gurume Sushi',
#   5.0,
#   '45 Carlton Street',
#   92),
#  ('Church St / Alexander St',
#   43.663722,
#   -79.380288,
#   10,
#   5,
#   'The Churchmouse: A Firkin Pub',
#   3.5,
#   '475 Church Street',
#   93),
#  ('Church St / Alexander St',
#   43.663722,
#   -79.380288,
#   10,
#   5,
#   'Burrito Bandidos',
#   4.0,
#   '2 Grosvenor Street',
#   94),
#  ('Church St / Alexander St',
#   43.663722,
#   -79.380288,
#   10,
#   5,
#   'Torch Pressed Sushi',
#   4.5,
#   '507 Church St',
#   95),
#  ('Church St / Alexander St',
#   43.663722,
#   -79.380288,
#   10,
#   5,
#   'Fushimi',
#   3.5,
#   '491 Church Street',
#   96),
#  ('Church St / Alexander St',
#   43.663722,
#   -79.380288,
#   10,
#   5,
#   'Zakkushi On Carlton',
#   4.0,
#   '193 Carlton Street',
#   97),
#  ('Church St / Alexander St',
#   43.663722,
#   -79.380288,
#   10,
#   5,
#   'The Blake House',
#   4.0,
#   '449 Jarvis Street',
#   98),
#  ('Church St / Alexander St',
#   43.663722,
#   -79.380288,
#   10,
#   5,
#   'Mr.Tonkatsu',
#   4.0,
#   '548 Yonge Street',
#   99),
#  ('Church St / Alexander St',
#   43.663722,
#   -79.380288,
#   10,
#   5,
#   'Mabu Generation',
#   4.0,
#   '575 Yonge Street',
#   100),
#  ('University Ave / Gerrard St W (East Side)',
#   43.657763,
#   -79.389165,
#   0,
#   6,
#   'Richmond Station',
#   4.5,
#   '1 Richmond Street W',
#   101),
#  ('University Ave / Gerrard St W (East Side)',
#   43.657763,
#   -79.389165,
#   0,
#   6,
#   'Dzo Viet Eatery',
#   4.0,
#   '308 Dundas Street W',
#   102),
#  ('University Ave / Gerrard St W (East Side)',
#   43.657763,
#   -79.389165,
#   0,
#   6,
#   'Sansotei Ramen',
#   4.0,
#   '179 Dundas Street W',
#   103),
#  ('University Ave / Gerrard St W (East Side)',
#   43.657763,
#   -79.389165,
#   0,
#   6,
#   'Omai Restaurant',
#   4.0,
#   '3 Baldwin Street',
#   104),
#  ('University Ave / Gerrard St W (East Side)',
#   43.657763,
#   -79.389165,
#   0,
#   6,
#   'Koh Lipe',
#   4.0,
#   '35 Baldwin Street',
#   105),
#  ('University Ave / Gerrard St W (East Side)',
#   43.657763,
#   -79.389165,
#   0,
#   6,
#   'Mercatto',
#   3.5,
#   '101 College Street',
#   106),
#  ('University Ave / Gerrard St W (East Side)',
#   43.657763,
#   -79.389165,
#   0,
#   6,
#   'The Keg Steakhouse + Bar - York Street',
#   4.0,
#   '165 York Street',
#   107),
#  ('University Ave / Gerrard St W (East Side)',
#   43.657763,
#   -79.389165,
#   0,
#   6,
#   'Adega Restaurante',
#   4.0,
#   '33 Elm St',
#   108),
#  ('University Ave / Gerrard St W (East Side)',
#   43.657763,
#   -79.389165,
#   0,
#   6,
#   'Gyubee Japanese Grill - Dundas',
#   4.5,
#   '157 Dundas St W',
#   109),
#  ('University Ave / Gerrard St W (East Side)',
#   43.657763,
#   -79.389165,
#   0,
#   6,
#   'Mogouyan Hand-Pulled Noodles',
#   4.5,
#   '124 Dundas St W',
#   110),
#  ('University Ave / Gerrard St W (East Side)',
#   43.657763,
#   -79.389165,
#   0,
#   6,
#   'The Queen And Beaver Public House',
#   4.0,
#   '35 Elm Street',
#   111),
#  ('University Ave / Gerrard St W (East Side)',
#   43.657763,
#   -79.389165,
#   0,
#   6,
#   'Ikkousha Ramen',
#   4.5,
#   '249 Queen Street W',
#   112),
#  ('University Ave / Gerrard St W (East Side)',
#   43.657763,
#   -79.389165,
#   0,
#   6,
#   'Banh Mi Boys',
#   4.0,
#   '399 Yonge Street',
#   113),
#  ('University Ave / Gerrard St W (East Side)',
#   43.657763,
#   -79.389165,
#   0,
#   6,
#   'Saigon Lotus',
#   4.5,
#   '6 St Andrew Street',
#   114),
#  ('University Ave / Gerrard St W (East Side)',
#   43.657763,
#   -79.389165,
#   0,
#   6,
#   'KINKA IZAKAYA ORIGINAL',
#   4.0,
#   '398 Church Street',
#   115),
#  ('University Ave / Gerrard St W (East Side)',
#   43.657763,
#   -79.389165,
#   0,
#   6,
#   'Manpuku Japanese Eatery',
#   4.0,
#   '105 McCaul Street',
#   116),
#  ('University Ave / Gerrard St W (East Side)',
#   43.657763,
#   -79.389165,
#   0,
#   6,
#   '1915 Lan Zhou Ramen',
#   4.0,
#   '185 Dundas Street W',
#   117),
#  ('University Ave / Gerrard St W (East Side)',
#   43.657763,
#   -79.389165,
#   0,
#   6,
#   'Katsuya',
#   4.5,
#   '66 Gerrard Street E',
#   118),
#  ('University Ave / Gerrard St W (East Side)',
#   43.657763,
#   -79.389165,
#   0,
#   6,
#   'Beerbistro',
#   4.0,
#   '18 King Street E',
#   119),
#  ('University Ave / Gerrard St W (East Side)',
#   43.657763,
#   -79.389165,
#   0,
#   6,
#   'Café La Gaffe',
#   3.5,
#   '24 Baldwin Street',
#   120),
#  ('Edward St / Yonge St',
#   43.656729,
#   -79.382736,
#   11,
#   7,
#   'The Queen And Beaver Public House',
#   4.0,
#   '35 Elm Street',
#   121),
#  ('Edward St / Yonge St',
#   43.656729,
#   -79.382736,
#   11,
#   7,
#   'Richmond Station',
#   4.5,
#   '1 Richmond Street W',
#   122),
#  ('Edward St / Yonge St',
#   43.656729,
#   -79.382736,
#   11,
#   7,
#   'Adega Restaurante',
#   4.0,
#   '33 Elm St',
#   123),
#  ('Edward St / Yonge St',
#   43.656729,
#   -79.382736,
#   11,
#   7,
#   'Mogouyan Hand-Pulled Noodles',
#   4.5,
#   '124 Dundas St W',
#   124),
#  ('Edward St / Yonge St',
#   43.656729,
#   -79.382736,
#   11,
#   7,
#   'Blaze Pizza',
#   4.5,
#   '10 Dundas St. East',
#   125),
#  ('Edward St / Yonge St',
#   43.656729,
#   -79.382736,
#   11,
#   7,
#   'Donatello Restaurant',
#   4.0,
#   '37 Elm Street',
#   126),
#  ('Edward St / Yonge St',
#   43.656729,
#   -79.382736,
#   11,
#   7,
#   "Barberian's Steak House",
#   4.0,
#   '7 Elm Street',
#   127),
#  ('Edward St / Yonge St',
#   43.656729,
#   -79.382736,
#   11,
#   7,
#   'Konjiki Ramen Downtown',
#   4.0,
#   '41 Elm Street',
#   128),
#  ('Edward St / Yonge St',
#   43.656729,
#   -79.382736,
#   11,
#   7,
#   'Moon Palace',
#   4.0,
#   '40 Dundas Street W',
#   129),
#  ('Edward St / Yonge St',
#   43.656729,
#   -79.382736,
#   11,
#   7,
#   'DonDon Izakaya',
#   3.0,
#   '130 Dundas Street West',
#   130),
#  ('Edward St / Yonge St',
#   43.656729,
#   -79.382736,
#   11,
#   7,
#   'Pai Northern Thai Kitchen',
#   4.5,
#   '18 Duncan Street',
#   131),
#  ('Edward St / Yonge St',
#   43.656729,
#   -79.382736,
#   11,
#   7,
#   'JOEY Eaton Centre',
#   3.5,
#   '1 Dundas St W',
#   132),
#  ('Edward St / Yonge St',
#   43.656729,
#   -79.382736,
#   11,
#   7,
#   'Salad King Restaurant',
#   3.5,
#   '340 Yonge Street',
#   133),
#  ('Edward St / Yonge St',
#   43.656729,
#   -79.382736,
#   11,
#   7,
#   'Congee Queen',
#   4.0,
#   '360 Yonge Street',
#   134),
#  ('Edward St / Yonge St',
#   43.656729,
#   -79.382736,
#   11,
#   7,
#   'Banh Mi Boys',
#   4.0,
#   '399 Yonge Street',
#   135),
#  ('Edward St / Yonge St',
#   43.656729,
#   -79.382736,
#   11,
#   7,
#   'Sansotei Ramen',
#   4.0,
#   '179 Dundas Street W',
#   136),
#  ('Edward St / Yonge St',
#   43.656729,
#   -79.382736,
#   11,
#   7,
#   'Thai On Yonge',
#   4.0,
#   '370 Yonge Street',
#   137),
#  ('Edward St / Yonge St',
#   43.656729,
#   -79.382736,
#   11,
#   7,
#   'Bangkok Garden Restaurant',
#   3.0,
#   '18 Elm Street',
#   138),
#  ('Edward St / Yonge St',
#   43.656729,
#   -79.382736,
#   11,
#   7,
#   'KINKA IZAKAYA ORIGINAL',
#   4.0,
#   '398 Church Street',
#   139),
#  ('Edward St / Yonge St',
#   43.656729,
#   -79.382736,
#   11,
#   7,
#   'Gyubee Japanese Grill - Dundas',
#   4.5,
#   '157 Dundas St W',
#   140),
#  ('Euclid Ave / Bloor St W',
#   43.664467,
#   -79.414783,
#   9,
#   8,
#   'Daldongnae Korean BBQ - Christie',
#   4.5,
#   '658 Bloor Street',
#   141),
#  ('Euclid Ave / Bloor St W',
#   43.664467,
#   -79.414783,
#   9,
#   8,
#   'Yummy Korean Food Restaurant',
#   4.0,
#   '620 Bloor Street W',
#   142),
#  ('Euclid Ave / Bloor St W',
#   43.664467,
#   -79.414783,
#   9,
#   8,
#   'Korean Village Restaurant',
#   4.0,
#   '628 Bloor Street W',
#   143),
#  ('Euclid Ave / Bloor St W',
#   43.664467,
#   -79.414783,
#   9,
#   8,
#   'Buk Chang Dong Soon Tofu',
#   4.0,
#   '691 Bloor Street W',
#   144),
#  ('Euclid Ave / Bloor St W',
#   43.664467,
#   -79.414783,
#   9,
#   8,
#   'KINKA IZAKAYA ANNEX',
#   4.0,
#   '559 Bloor St W',
#   145),
#  ('Euclid Ave / Bloor St W',
#   43.664467,
#   -79.414783,
#   9,
#   8,
#   'Sunrise House',
#   4.0,
#   '661 Bloor Street W',
#   146),
#  ('Euclid Ave / Bloor St W',
#   43.664467,
#   -79.414783,
#   9,
#   8,
#   'Insomnia Restaurant & Lounge',
#   4.0,
#   '563 Bloor Street W',
#   147),
#  ('Euclid Ave / Bloor St W',
#   43.664467,
#   -79.414783,
#   9,
#   8,
#   'Hancook Cheese Dakgalbi',
#   4.0,
#   '605 Bloor Street W',
#   148),
#  ('Euclid Ave / Bloor St W',
#   43.664467,
#   -79.414783,
#   9,
#   8,
#   'MaMa Chef Korean Restaurant',
#   4.0,
#   '648 Bloor Street W',
#   149),
#  ('Euclid Ave / Bloor St W',
#   43.664467,
#   -79.414783,
#   9,
#   8,
#   'Paldo Gangsan',
#   4.5,
#   '694 Bloor Street  W',
#   150),
#  ('Euclid Ave / Bloor St W',
#   43.664467,
#   -79.414783,
#   9,
#   8,
#   'Ninetails Coffee Bar',
#   4.5,
#   '651 Bloor Street W',
#   151),
#  ('Euclid Ave / Bloor St W',
#   43.664467,
#   -79.414783,
#   9,
#   8,
#   'KINTON RAMEN',
#   3.5,
#   '668 Bloor Street W',
#   152),
#  ('Euclid Ave / Bloor St W',
#   43.664467,
#   -79.414783,
#   9,
#   8,
#   'Snakes & Lattes Annex',
#   4.0,
#   '600 Bloor Street W',
#   153),
#  ('Euclid Ave / Bloor St W',
#   43.664467,
#   -79.414783,
#   9,
#   8,
#   'Her Chef',
#   4.5,
#   '599 Bloor Street W',
#   154),
#  ('Euclid Ave / Bloor St W',
#   43.664467,
#   -79.414783,
#   9,
#   8,
#   'Arisu Korean BBQ & Sushi',
#   3.5,
#   '584 Bloor Street W',
#   155),
#  ('Euclid Ave / Bloor St W',
#   43.664467,
#   -79.414783,
#   9,
#   8,
#   'Rasa',
#   4.5,
#   '196 Robert Street',
#   156),
#  ('Euclid Ave / Bloor St W',
#   43.664467,
#   -79.414783,
#   9,
#   8,
#   'Kintori Yakitori Izakaya',
#   3.5,
#   '668 Bloor Street W',
#   157),
#  ('Euclid Ave / Bloor St W',
#   43.664467,
#   -79.414783,
#   9,
#   8,
#   'Mr.Tonkatsu',
#   4.0,
#   '520 Bloor Street W',
#   158),
#  ('Euclid Ave / Bloor St W',
#   43.664467,
#   -79.414783,
#   9,
#   8,
#   'Hodo Kwaja',
#   4.5,
#   '656 Bloor Street W',
#   159),
#  ('Euclid Ave / Bloor St W',
#   43.664467,
#   -79.414783,
#   9,
#   8,
#   'Yasu',
#   4.5,
#   '81 Harbord Street',
#   160),
#  ('Yonge St / Aylmer Ave',
#   43.675492,
#   -79.388858,
#   13,
#   9,
#   'Mineral',
#   4.5,
#   '1027 Yonge Street',
#   161),
#  ('Yonge St / Aylmer Ave',
#   43.675492,
#   -79.388858,
#   13,
#   9,
#   "Joso's",
#   4.5,
#   '202 Davenport Road',
#   162),
#  ('Yonge St / Aylmer Ave',
#   43.675492,
#   -79.388858,
#   13,
#   9,
#   'Portici',
#   4.0,
#   '6 Scollard Street',
#   163),
#  ('Yonge St / Aylmer Ave',
#   43.675492,
#   -79.388858,
#   13,
#   9,
#   'Trattoria Nervosa',
#   4.0,
#   '75 Yorkville Avenue',
#   164),
#  ('Yonge St / Aylmer Ave',
#   43.675492,
#   -79.388858,
#   13,
#   9,
#   'The Keg Steakhouse + Bar',
#   4.0,
#   '515 Jarvis Street',
#   165),
#  ('Yonge St / Aylmer Ave',
#   43.675492,
#   -79.388858,
#   13,
#   9,
#   'PLANTA Yorkville',
#   4.0,
#   '1221 Bay Street',
#   166),
#  ('Yonge St / Aylmer Ave',
#   43.675492,
#   -79.388858,
#   13,
#   9,
#   'Scaramouche Restaurant Pasta Bar & Grill',
#   4.5,
#   '1 Benvenuto Place',
#   167),
#  ('Yonge St / Aylmer Ave',
#   43.675492,
#   -79.388858,
#   13,
#   9,
#   'Café Boulud',
#   3.5,
#   '60 Yorkville Avenue',
#   168),
#  ('Yonge St / Aylmer Ave',
#   43.675492,
#   -79.388858,
#   13,
#   9,
#   'Black Camel',
#   4.5,
#   '4 Crescent Road',
#   169),
#  ('Yonge St / Aylmer Ave',
#   43.675492,
#   -79.388858,
#   13,
#   9,
#   'Lee Chen Bistro',
#   3.5,
#   '813 Yonge Street',
#   170),
#  ('Yonge St / Aylmer Ave',
#   43.675492,
#   -79.388858,
#   13,
#   9,
#   'Blu Ristorante',
#   4.0,
#   '90 Avenue Road',
#   171),
#  ('Yonge St / Aylmer Ave',
#   43.675492,
#   -79.388858,
#   13,
#   9,
#   'Playa Cabana',
#   4.0,
#   '111 Dupont Street',
#   172),
#  ('Yonge St / Aylmer Ave',
#   43.675492,
#   -79.388858,
#   13,
#   9,
#   'Happy Burger',
#   4.5,
#   '881 Yonge Street',
#   173),
#  ('Yonge St / Aylmer Ave',
#   43.675492,
#   -79.388858,
#   13,
#   9,
#   'Kiro Sushi',
#   4.0,
#   '4 Collier Street',
#   174),
#  ('Yonge St / Aylmer Ave',
#   43.675492,
#   -79.388858,
#   13,
#   9,
#   'Bhoj Indian Cuisine',
#   4.0,
#   '21 Davenport Road',
#   175),
#  ('Yonge St / Aylmer Ave',
#   43.675492,
#   -79.388858,
#   13,
#   9,
#   'The Rebel House',
#   3.5,
#   '1068 Yonge Street',
#   176),
#  ('Yonge St / Aylmer Ave',
#   43.675492,
#   -79.388858,
#   13,
#   9,
#   'Sassafraz',
#   3.5,
#   '100 Cumberland Street',
#   177),
#  ('Yonge St / Aylmer Ave',
#   43.675492,
#   -79.388858,
#   13,
#   9,
#   'Utsav',
#   4.0,
#   '69 Yorkville Ave',
#   178),
#  ('Yonge St / Aylmer Ave',
#   43.675492,
#   -79.388858,
#   13,
#   9,
#   'Fieramosca',
#   4.5,
#   '36A Prince Arthur Avenue',
#   179),
#  ('Yonge St / Aylmer Ave',
#   43.675492,
#   -79.388858,
#   13,
#   9,
#   'The Oxley',
#   4.0,
#   '121 Yorkville Avenue',
#   180),
#  ('Davenport Rd / Avenue Rd',
#   43.674991,
#   -79.396273,
#   3,
#   10,
#   "Joso's",
#   4.5,
#   '202 Davenport Road',
#   181),
#  ('Davenport Rd / Avenue Rd',
#   43.674991,
#   -79.396273,
#   3,
#   10,
#   'Ristorante Sotto Sotto',
#   4.0,
#   '120 Avenue Road',
#   182),
#  ('Davenport Rd / Avenue Rd',
#   43.674991,
#   -79.396273,
#   3,
#   10,
#   'Osteria Giulia',
#   4.5,
#   '134 Avenue Road',
#   183),
#  ('Davenport Rd / Avenue Rd',
#   43.674991,
#   -79.396273,
#   3,
#   10,
#   'Blu Ristorante',
#   4.0,
#   '90 Avenue Road',
#   184),
#  ('Davenport Rd / Avenue Rd',
#   43.674991,
#   -79.396273,
#   3,
#   10,
#   'Playa Cabana',
#   4.0,
#   '111 Dupont Street',
#   185),
#  ('Davenport Rd / Avenue Rd',
#   43.674991,
#   -79.396273,
#   3,
#   10,
#   'Scaramouche Restaurant Pasta Bar & Grill',
#   4.5,
#   '1 Benvenuto Place',
#   186),
#  ('Davenport Rd / Avenue Rd',
#   43.674991,
#   -79.396273,
#   3,
#   10,
#   'Mimi Chinese',
#   4.0,
#   '265 Davenport Road',
#   187),
#  ('Davenport Rd / Avenue Rd',
#   43.674991,
#   -79.396273,
#   3,
#   10,
#   'The Oxley',
#   4.0,
#   '121 Yorkville Avenue',
#   188),
#  ('Davenport Rd / Avenue Rd',
#   43.674991,
#   -79.396273,
#   3,
#   10,
#   'Le Paradis Brasserie Bistro',
#   3.5,
#   '166 Bedford Road',
#   189),
#  ('Davenport Rd / Avenue Rd',
#   43.674991,
#   -79.396273,
#   3,
#   10,
#   'Trattoria Nervosa',
#   4.0,
#   '75 Yorkville Avenue',
#   190),
#  ('Davenport Rd / Avenue Rd',
#   43.674991,
#   -79.396273,
#   3,
#   10,
#   'Fieramosca',
#   4.5,
#   '36A Prince Arthur Avenue',
#   191),
#  ('Davenport Rd / Avenue Rd',
#   43.674991,
#   -79.396273,
#   3,
#   10,
#   'Pisac Peruvian Bistro',
#   4.5,
#   '16 Dupont St',
#   192),
#  ('Davenport Rd / Avenue Rd',
#   43.674991,
#   -79.396273,
#   3,
#   10,
#   'PLANTA Yorkville',
#   4.0,
#   '1221 Bay Street',
#   193),
#  ('Davenport Rd / Avenue Rd',
#   43.674991,
#   -79.396273,
#   3,
#   10,
#   'Figures',
#   3.5,
#   '137 Avenue Road',
#   194),
#  ('Davenport Rd / Avenue Rd',
#   43.674991,
#   -79.396273,
#   3,
#   10,
#   'Sassafraz',
#   3.5,
#   '100 Cumberland Street',
#   195),
#  ('Davenport Rd / Avenue Rd',
#   43.674991,
#   -79.396273,
#   3,
#   10,
#   'Gyubee Japanese Grill - Bloor',
#   4.0,
#   '335 Bloor Street W',
#   196),
#  ('Davenport Rd / Avenue Rd',
#   43.674991,
#   -79.396273,
#   3,
#   10,
#   'Mineral',
#   4.5,
#   '1027 Yonge Street',
#   197),
#  ('Davenport Rd / Avenue Rd',
#   43.674991,
#   -79.396273,
#   3,
#   10,
#   'Café Boulud',
#   3.5,
#   '60 Yorkville Avenue',
#   198),
#  ('Davenport Rd / Avenue Rd',
#   43.674991,
#   -79.396273,
#   3,
#   10,
#   'Opus Restaurant',
#   4.0,
#   '37 Prince Arthur Avenue',
#   199),
#  ('Davenport Rd / Avenue Rd',
#   43.674991,
#   -79.396273,
#   3,
#   10,
#   'Utsav',
#   4.0,
#   '69 Yorkville Ave',
#   200),
#  ('Yonge St / Yorkville Ave',
#   43.671944,
#   -79.387778,
#   1,
#   11,
#   'PLANTA Yorkville',
#   4.0,
#   '1221 Bay Street',
#   201),
#  ('Yonge St / Yorkville Ave',
#   43.671944,
#   -79.387778,
#   1,
#   11,
#   'Portici',
#   4.0,
#   '6 Scollard Street',
#   202),
#  ('Yonge St / Yorkville Ave',
#   43.671944,
#   -79.387778,
#   1,
#   11,
#   'Trattoria Nervosa',
#   4.0,
#   '75 Yorkville Avenue',
#   203),
#  ('Yonge St / Yorkville Ave',
#   43.671944,
#   -79.387778,
#   1,
#   11,
#   'Eataly Toronto',
#   3.5,
#   '55 Bloor Street W',
#   204),
#  ('Yonge St / Yorkville Ave',
#   43.671944,
#   -79.387778,
#   1,
#   11,
#   'Café Boulud',
#   3.5,
#   '60 Yorkville Avenue',
#   205),
#  ('Yonge St / Yorkville Ave',
#   43.671944,
#   -79.387778,
#   1,
#   11,
#   'Sassafraz',
#   3.5,
#   '100 Cumberland Street',
#   206),
#  ('Yonge St / Yorkville Ave',
#   43.671944,
#   -79.387778,
#   1,
#   11,
#   'Lee Chen Bistro',
#   3.5,
#   '813 Yonge Street',
#   207),
#  ('Yonge St / Yorkville Ave',
#   43.671944,
#   -79.387778,
#   1,
#   11,
#   'Cafe Landwer - Yonge & Bloor',
#   4.0,
#   '33 Bloor St E',
#   208),
#  ('Yonge St / Yorkville Ave',
#   43.671944,
#   -79.387778,
#   1,
#   11,
#   'The Oxley',
#   4.0,
#   '121 Yorkville Avenue',
#   209),
#  ('Yonge St / Yorkville Ave',
#   43.671944,
#   -79.387778,
#   1,
#   11,
#   'Mogouyan Hand-Pulled Noodles',
#   4.0,
#   '760 Yonge Street',
#   210),
#  ('Yonge St / Yorkville Ave',
#   43.671944,
#   -79.387778,
#   1,
#   11,
#   'Utsav',
#   4.0,
#   '69 Yorkville Ave',
#   211),
#  ('Yonge St / Yorkville Ave',
#   43.671944,
#   -79.387778,
#   1,
#   11,
#   'Naan & Kabob',
#   4.0,
#   '691 Yonge Street',
#   212),
#  ('Yonge St / Yorkville Ave',
#   43.671944,
#   -79.387778,
#   1,
#   11,
#   'Buca Yorkville',
#   4.0,
#   '53 Scollard Street',
#   213),
#  ('Yonge St / Yorkville Ave',
#   43.671944,
#   -79.387778,
#   1,
#   11,
#   'Kiro Sushi',
#   4.0,
#   '4 Collier Street',
#   214),
#  ('Yonge St / Yorkville Ave',
#   43.671944,
#   -79.387778,
#   1,
#   11,
#   'The Keg Steakhouse + Bar',
#   4.0,
#   '515 Jarvis Street',
#   215),
#  ('Yonge St / Yorkville Ave',
#   43.671944,
#   -79.387778,
#   1,
#   11,
#   'holts café',
#   3.5,
#   '50 Bloor Street West',
#   216),
#  ('Yonge St / Yorkville Ave',
#   43.671944,
#   -79.387778,
#   1,
#   11,
#   "Joso's",
#   4.5,
#   '202 Davenport Road',
#   217),
#  ('Yonge St / Yorkville Ave',
#   43.671944,
#   -79.387778,
#   1,
#   11,
#   'Bhoj Indian Cuisine',
#   4.0,
#   '21 Davenport Road',
#   218),
#  ('Yonge St / Yorkville Ave',
#   43.671944,
#   -79.387778,
#   1,
#   11,
#   'Jack Astor’s',
#   3.0,
#   '2 Bloor Street East',
#   219),
#  ('Yonge St / Yorkville Ave',
#   43.671944,
#   -79.387778,
#   1,
#   11,
#   'Dynasty Chinese Cuisine',
#   3.0,
#   '69 Yorkville Avenue',
#   220),
#  ('Dundas St E / Broadview Ave',
#   43.662365,
#   -79.351104,
#   15,
#   12,
#   'Lady Marmalade',
#   4.0,
#   '265 Broadview Avenue',
#   221),
#  ('Dundas St E / Broadview Ave',
#   43.662365,
#   -79.351104,
#   15,
#   12,
#   'White Lily Diner',
#   4.5,
#   '678 Queen Street E',
#   222),
#  ('Dundas St E / Broadview Ave',
#   43.662365,
#   -79.351104,
#   15,
#   12,
#   'The Comrade',
#   4.0,
#   '758 Queen Street E',
#   223),
#  ('Dundas St E / Broadview Ave',
#   43.662365,
#   -79.351104,
#   15,
#   12,
#   'Completo',
#   4.5,
#   '337 Broadview Ave',
#   224),
#  ('Dundas St E / Broadview Ave',
#   43.662365,
#   -79.351104,
#   15,
#   12,
#   'Tabule Middle Eastern Cuisine',
#   4.0,
#   '810 Queen Street  E',
#   225),
#  ('Dundas St E / Broadview Ave',
#   43.662365,
#   -79.351104,
#   15,
#   12,
#   'Wok & Roast Chinese BBQ',
#   3.5,
#   '349 Broadview Ave',
#   226),
#  ('Dundas St E / Broadview Ave',
#   43.662365,
#   -79.351104,
#   15,
#   12,
#   'O’SOMAE',
#   4.5,
#   '357 Broadview Ave',
#   227),
#  ('Dundas St E / Broadview Ave',
#   43.662365,
#   -79.351104,
#   15,
#   12,
#   'La Carnita',
#   3.5,
#   '780 Queen Street E',
#   228),
#  ('Dundas St E / Broadview Ave',
#   43.662365,
#   -79.351104,
#   15,
#   12,
#   'ēst Restaurant',
#   4.0,
#   '729 Queen Street E',
#   229),
#  ('Dundas St E / Broadview Ave',
#   43.662365,
#   -79.351104,
#   15,
#   12,
#   'Dine & Dim',
#   4.5,
#   '633 Gerrard St E',
#   230),
#  ('Dundas St E / Broadview Ave',
#   43.662365,
#   -79.351104,
#   15,
#   12,
#   'Oji Seichi',
#   4.0,
#   '354 Broadview Avenue',
#   231),
#  ('Dundas St E / Broadview Ave',
#   43.662365,
#   -79.351104,
#   15,
#   12,
#   'Brickworks Cider House',
#   4.0,
#   '709 Queen Street E',
#   232),
#  ('Dundas St E / Broadview Ave',
#   43.662365,
#   -79.351104,
#   15,
#   12,
#   'Riverside Burgers',
#   4.5,
#   '688 Queen St E',
#   233),
#  ('Dundas St E / Broadview Ave',
#   43.662365,
#   -79.351104,
#   15,
#   12,
#   'Eastside Social',
#   4.5,
#   '1008 Queen Street E',
#   234),
#  ('Dundas St E / Broadview Ave',
#   43.662365,
#   -79.351104,
#   15,
#   12,
#   'Mi Mi Restaurant',
#   4.0,
#   '686A Gerrard Street E',
#   235),
#  ('Dundas St E / Broadview Ave',
#   43.662365,
#   -79.351104,
#   15,
#   12,
#   'Gusto 501',
#   4.0,
#   '501 King Street E',
#   236),
#  ('Dundas St E / Broadview Ave',
#   43.662365,
#   -79.351104,
#   15,
#   12,
#   'Batifole Restaurant',
#   4.0,
#   '744 Gerrard Street E',
#   237),
#  ('Dundas St E / Broadview Ave',
#   43.662365,
#   -79.351104,
#   15,
#   12,
#   'Wynona',
#   4.5,
#   '819 Gerrard Street E',
#   238),
#  ('Dundas St E / Broadview Ave',
#   43.662365,
#   -79.351104,
#   15,
#   12,
#   'Isaan Der',
#   4.0,
#   '730 Queen St E',
#   239),
#  ('Dundas St E / Broadview Ave',
#   43.662365,
#   -79.351104,
#   15,
#   12,
#   'Souk Tabule',
#   4.5,
#   '494 Front Street E',
#   240),
#  ('Front St W / Yonge St (Hockey Hall of Fame)',
#   43.646144,
#   -79.377962,
#   6,
#   13,
#   'Richmond Station',
#   4.5,
#   '1 Richmond Street W',
#   241),
#  ('Front St W / Yonge St (Hockey Hall of Fame)',
#   43.646144,
#   -79.377962,
#   6,
#   13,
#   'Pai Northern Thai Kitchen',
#   4.5,
#   '18 Duncan Street',
#   242),
#  ('Front St W / Yonge St (Hockey Hall of Fame)',
#   43.646144,
#   -79.377962,
#   6,
#   13,
#   'Chotto Matte',
#   4.0,
#   '161 Bay Street',
#   243),
#  ('Front St W / Yonge St (Hockey Hall of Fame)',
#   43.646144,
#   -79.377962,
#   6,
#   13,
#   'Beerbistro',
#   4.0,
#   '18 King Street E',
#   244),
#  ('Front St W / Yonge St (Hockey Hall of Fame)',
#   43.646144,
#   -79.377962,
#   6,
#   13,
#   'The Keg Steakhouse + Bar - Esplanade',
#   4.0,
#   '26 The Esplanade',
#   245),
#  ('Front St W / Yonge St (Hockey Hall of Fame)',
#   43.646144,
#   -79.377962,
#   6,
#   13,
#   'Canoe',
#   4.0,
#   '66 Wellington Street  W',
#   246),
#  ('Front St W / Yonge St (Hockey Hall of Fame)',
#   43.646144,
#   -79.377962,
#   6,
#   13,
#   'Jump Restaurant',
#   3.5,
#   '18 Wellington Street W',
#   247),
#  ('Front St W / Yonge St (Hockey Hall of Fame)',
#   43.646144,
#   -79.377962,
#   6,
#   13,
#   'The Old Spaghetti Factory',
#   3.5,
#   '54 The Esplanade',
#   248),
#  ('Front St W / Yonge St (Hockey Hall of Fame)',
#   43.646144,
#   -79.377962,
#   6,
#   13,
#   "Biff's Bistro",
#   3.5,
#   '4 Front Street  E',
#   249),
#  ('Front St W / Yonge St (Hockey Hall of Fame)',
#   43.646144,
#   -79.377962,
#   6,
#   13,
#   'Library Bar',
#   4.0,
#   '100 Front Street W',
#   250),
#  ('Front St W / Yonge St (Hockey Hall of Fame)',
#   43.646144,
#   -79.377962,
#   6,
#   13,
#   'King Taps',
#   4.0,
#   '100 King Street W',
#   251),
#  ('Front St W / Yonge St (Hockey Hall of Fame)',
#   43.646144,
#   -79.377962,
#   6,
#   13,
#   'Ki Modern Japanese + Bar',
#   3.5,
#   '181 Bay Street',
#   252),
#  ('Front St W / Yonge St (Hockey Hall of Fame)',
#   43.646144,
#   -79.377962,
#   6,
#   13,
#   'Byblos',
#   4.5,
#   '11 Duncan Street',
#   253),
#  ('Front St W / Yonge St (Hockey Hall of Fame)',
#   43.646144,
#   -79.377962,
#   6,
#   13,
#   'Oliver & Bonacini Café Grill',
#   3.0,
#   '33 Yonge Street',
#   254),
#  ('Front St W / Yonge St (Hockey Hall of Fame)',
#   43.646144,
#   -79.377962,
#   6,
#   13,
#   'Cactus Club Cafe',
#   4.0,
#   '77 Adelaide Street W',
#   255),
#  ('Front St W / Yonge St (Hockey Hall of Fame)',
#   43.646144,
#   -79.377962,
#   6,
#   13,
#   'Bymark',
#   3.5,
#   '66 Wellington Street W',
#   256),
#  ('Front St W / Yonge St (Hockey Hall of Fame)',
#   43.646144,
#   -79.377962,
#   6,
#   13,
#   'Miku',
#   4.0,
#   '105-10 Bay Street',
#   257),
#  ('Front St W / Yonge St (Hockey Hall of Fame)',
#   43.646144,
#   -79.377962,
#   6,
#   13,
#   'The Keg Steakhouse + Bar - York Street',
#   4.0,
#   '165 York Street',
#   258),
#  ('Front St W / Yonge St (Hockey Hall of Fame)',
#   43.646144,
#   -79.377962,
#   6,
#   13,
#   'WVRST Union Station',
#   4.0,
#   '65 Front Street West',
#   259),
#  ('Front St W / Yonge St (Hockey Hall of Fame)',
#   43.646144,
#   -79.377962,
#   6,
#   13,
#   'Real Sports',
#   3.5,
#   '15 York Street',
#   260),
#  ('Gerrard St E / River St',
#   43.663993,
#   -79.358534,
#   8,
#   14,
#   'The House On Parliament',
#   4.0,
#   '454 Parliament Street',
#   261),
#  ('Gerrard St E / River St',
#   43.663993,
#   -79.358534,
#   8,
#   14,
#   'Zakkushi On Carlton',
#   4.0,
#   '193 Carlton Street',
#   262),
#  ('Gerrard St E / River St',
#   43.663993,
#   -79.358534,
#   8,
#   14,
#   'Stout Irish Pub',
#   4.0,
#   '221 Carlton Street',
#   263),
#  ('Gerrard St E / River St',
#   43.663993,
#   -79.358534,
#   8,
#   14,
#   'White Lily Diner',
#   4.5,
#   '678 Queen Street E',
#   264),
#  ('Gerrard St E / River St',
#   43.663993,
#   -79.358534,
#   8,
#   14,
#   'Saigon PAI',
#   4.5,
#   '446 Parliament Street',
#   265),
#  ('Gerrard St E / River St',
#   43.663993,
#   -79.358534,
#   8,
#   14,
#   'The Comrade',
#   4.0,
#   '758 Queen Street E',
#   266),
#  ('Gerrard St E / River St',
#   43.663993,
#   -79.358534,
#   8,
#   14,
#   'Tabule Middle Eastern Cuisine',
#   4.0,
#   '810 Queen Street  E',
#   267),
#  ('Gerrard St E / River St',
#   43.663993,
#   -79.358534,
#   8,
#   14,
#   'Maya Bay Thai',
#   4.5,
#   '252 Carlton Street',
#   268),
#  ('Gerrard St E / River St',
#   43.663993,
#   -79.358534,
#   8,
#   14,
#   'Lady Marmalade',
#   4.0,
#   '265 Broadview Avenue',
#   269),
#  ('Gerrard St E / River St',
#   43.663993,
#   -79.358534,
#   8,
#   14,
#   'Batifole Restaurant',
#   4.0,
#   '744 Gerrard Street E',
#   270),
#  ('Gerrard St E / River St',
#   43.663993,
#   -79.358534,
#   8,
#   14,
#   'O’SOMAE',
#   4.5,
#   '357 Broadview Ave',
#   271),
#  ('Gerrard St E / River St',
#   43.663993,
#   -79.358534,
#   8,
#   14,
#   'Oji Seichi',
#   4.0,
#   '354 Broadview Avenue',
#   272),
#  ('Gerrard St E / River St',
#   43.663993,
#   -79.358534,
#   8,
#   14,
#   'Completo',
#   4.5,
#   '337 Broadview Ave',
#   273),
#  ('Gerrard St E / River St',
#   43.663993,
#   -79.358534,
#   8,
#   14,
#   'Mi Mi Restaurant',
#   4.0,
#   '686A Gerrard Street E',
#   274),
#  ('Gerrard St E / River St',
#   43.663993,
#   -79.358534,
#   8,
#   14,
#   'La Carnita',
#   3.5,
#   '780 Queen Street E',
#   275),
#  ('Gerrard St E / River St',
#   43.663993,
#   -79.358534,
#   8,
#   14,
#   'ēst Restaurant',
#   4.0,
#   '729 Queen Street E',
#   276),
#  ('Gerrard St E / River St',
#   43.663993,
#   -79.358534,
#   8,
#   14,
#   "F'Amelia",
#   3.5,
#   '12 Amelia Street',
#   277),
#  ('Gerrard St E / River St',
#   43.663993,
#   -79.358534,
#   8,
#   14,
#   'Wok & Roast Chinese BBQ',
#   3.5,
#   '349 Broadview Ave',
#   278),
#  ('Gerrard St E / River St',
#   43.663993,
#   -79.358534,
#   8,
#   14,
#   'Brickworks Cider House',
#   4.0,
#   '709 Queen Street E',
#   279),
#  ('Gerrard St E / River St',
#   43.663993,
#   -79.358534,
#   8,
#   14,
#   'Salt and Tobacco',
#   4.5,
#   '521 Parliament Street',
#   280),
#  ('Jarvis St / Dundas St E',
#   43.657266,
#   -79.374756,
#   13,
#   15,
#   'Richmond Station',
#   4.5,
#   '1 Richmond Street W',
#   281),
#  ('Jarvis St / Dundas St E',
#   43.657266,
#   -79.374756,
#   13,
#   15,
#   'Hokkaido Ramen Santouka',
#   4.0,
#   '91 Dundas Street E',
#   282),
#  ('Jarvis St / Dundas St E',
#   43.657266,
#   -79.374756,
#   13,
#   15,
#   'Gyukatsu Kyoto Katsugyu',
#   4.0,
#   '134 Dundas Street E',
#   283),
#  ('Jarvis St / Dundas St E',
#   43.657266,
#   -79.374756,
#   13,
#   15,
#   'George Restaurant',
#   4.5,
#   '111 Queen Street E',
#   284),
#  ('Jarvis St / Dundas St E',
#   43.657266,
#   -79.374756,
#   13,
#   15,
#   'KINKA IZAKAYA ORIGINAL',
#   4.0,
#   '398 Church Street',
#   285),
#  ('Jarvis St / Dundas St E',
#   43.657266,
#   -79.374756,
#   13,
#   15,
#   'Page One',
#   4.0,
#   '106 Mutual Street',
#   286),
#  ('Jarvis St / Dundas St E',
#   43.657266,
#   -79.374756,
#   13,
#   15,
#   'Katsuya',
#   4.5,
#   '66 Gerrard Street E',
#   287),
#  ('Jarvis St / Dundas St E',
#   43.657266,
#   -79.374756,
#   13,
#   15,
#   'J San Sushi Bar',
#   4.5,
#   '186 Jarvis Street',
#   288),
#  ('Jarvis St / Dundas St E',
#   43.657266,
#   -79.374756,
#   13,
#   15,
#   'Blaze Pizza',
#   4.5,
#   '10 Dundas St. East',
#   289),
#  ('Jarvis St / Dundas St E',
#   43.657266,
#   -79.374756,
#   13,
#   15,
#   'The Carbon Bar',
#   4.0,
#   '99 Queen Street East',
#   290),
#  ('Jarvis St / Dundas St E',
#   43.657266,
#   -79.374756,
#   13,
#   15,
#   'Pearl Diver',
#   4.0,
#   '100 Adelaide Street E',
#   291),
#  ('Jarvis St / Dundas St E',
#   43.657266,
#   -79.374756,
#   13,
#   15,
#   'The Keg Steakhouse + Bar - York Street',
#   4.0,
#   '165 York Street',
#   292),
#  ('Jarvis St / Dundas St E',
#   43.657266,
#   -79.374756,
#   13,
#   15,
#   'KINTON RAMEN',
#   4.0,
#   '396 Church Street',
#   293),
#  ('Jarvis St / Dundas St E',
#   43.657266,
#   -79.374756,
#   13,
#   15,
#   'Beerbistro',
#   4.0,
#   '18 King Street E',
#   294),
#  ('Jarvis St / Dundas St E',
#   43.657266,
#   -79.374756,
#   13,
#   15,
#   'Cafe Oro Di Napoli',
#   4.5,
#   '75 Jarvis Street',
#   295),
#  ('Jarvis St / Dundas St E',
#   43.657266,
#   -79.374756,
#   13,
#   15,
#   'Zakkushi On Carlton',
#   4.0,
#   '193 Carlton Street',
#   296),
#  ('Jarvis St / Dundas St E',
#   43.657266,
#   -79.374756,
#   13,
#   15,
#   'The Senator',
#   4.0,
#   '249 Victoria Street',
#   297),
#  ('Jarvis St / Dundas St E',
#   43.657266,
#   -79.374756,
#   13,
#   15,
#   'Banh Mi Boys',
#   4.0,
#   '399 Yonge Street',
#   298),
#  ('Jarvis St / Dundas St E',
#   43.657266,
#   -79.374756,
#   13,
#   15,
#   'Egg Club',
#   4.5,
#   '88 Dundas Street E',
#   299),
#  ('Jarvis St / Dundas St E',
#   43.657266,
#   -79.374756,
#   13,
#   15,
#   'Adega Restaurante',
#   4.0,
#   '33 Elm St',
#   300),
#  ('Logan Av / Gerrard St E',
#   43.6672144,
#   -79.3452697,
#   14,
#   16,
#   'The Real Jerk',
#   3.5,
#   '842 Gerrard Street E',
#   301),
#  ('Logan Av / Gerrard St E',
#   43.6672144,
#   -79.3452697,
#   14,
#   16,
#   'Wynona',
#   4.5,
#   '819 Gerrard Street E',
#   302),
#  ('Logan Av / Gerrard St E',
#   43.6672144,
#   -79.3452697,
#   14,
#   16,
#   'Batifole Restaurant',
#   4.0,
#   '744 Gerrard Street E',
#   303),
#  ('Logan Av / Gerrard St E',
#   43.6672144,
#   -79.3452697,
#   14,
#   16,
#   "Gare De L'est",
#   3.5,
#   '1190 Dundas Street E',
#   304),
#  ('Logan Av / Gerrard St E',
#   43.6672144,
#   -79.3452697,
#   14,
#   16,
#   'Mi Mi Restaurant',
#   4.0,
#   '686A Gerrard Street E',
#   305),
#  ('Logan Av / Gerrard St E',
#   43.6672144,
#   -79.3452697,
#   14,
#   16,
#   'Ascari',
#   4.0,
#   '1111 Queen Street E',
#   306),
#  ('Logan Av / Gerrard St E',
#   43.6672144,
#   -79.3452697,
#   14,
#   16,
#   'Maple Leaf Tavern',
#   4.0,
#   '955 Gerrard Street E',
#   307),
#  ('Logan Av / Gerrard St E',
#   43.6672144,
#   -79.3452697,
#   14,
#   16,
#   'Hailed Coffee',
#   4.5,
#   '801 Gerrard Street E',
#   308),
#  ('Logan Av / Gerrard St E',
#   43.6672144,
#   -79.3452697,
#   14,
#   16,
#   'Chula Taberna Mexicana',
#   4.0,
#   '1058 Gerrard Street E',
#   309),
#  ('Logan Av / Gerrard St E',
#   43.6672144,
#   -79.3452697,
#   14,
#   16,
#   'Eastside Social',
#   4.5,
#   '1008 Queen Street E',
#   310),
#  ('Logan Av / Gerrard St E',
#   43.6672144,
#   -79.3452697,
#   14,
#   16,
#   'White Lily Diner',
#   4.5,
#   '678 Queen Street E',
#   311),
#  ('Logan Av / Gerrard St E',
#   43.6672144,
#   -79.3452697,
#   14,
#   16,
#   'Tabule Middle Eastern Cuisine',
#   4.0,
#   '810 Queen Street  E',
#   312),
#  ('Logan Av / Gerrard St E',
#   43.6672144,
#   -79.3452697,
#   14,
#   16,
#   'The Comrade',
#   4.0,
#   '758 Queen Street E',
#   313),
#  ('Logan Av / Gerrard St E',
#   43.6672144,
#   -79.3452697,
#   14,
#   16,
#   'Bach Yen',
#   4.0,
#   '738 Gerrard Street E',
#   314),
#  ('Logan Av / Gerrard St E',
#   43.6672144,
#   -79.3452697,
#   14,
#   16,
#   'Lady Marmalade',
#   4.0,
#   '265 Broadview Avenue',
#   315),
#  ('Logan Av / Gerrard St E',
#   43.6672144,
#   -79.3452697,
#   14,
#   16,
#   'Maker Pizza',
#   4.5,
#   '105A - 388 Carlaw Avenue',
#   316),
#  ('Logan Av / Gerrard St E',
#   43.6672144,
#   -79.3452697,
#   14,
#   16,
#   'Dine & Dim',
#   4.5,
#   '633 Gerrard St E',
#   317),
#  ('Logan Av / Gerrard St E',
#   43.6672144,
#   -79.3452697,
#   14,
#   16,
#   'EAT BKK Thai Kitchen',
#   4.0,
#   '898 Queen Street E',
#   318),
#  ('Logan Av / Gerrard St E',
#   43.6672144,
#   -79.3452697,
#   14,
#   16,
#   'CrowdedHouse',
#   4.5,
#   '1161 Queen Street E',
#   319),
#  ('Logan Av / Gerrard St E',
#   43.6672144,
#   -79.3452697,
#   14,
#   16,
#   "Ed's Real Scoop",
#   4.5,
#   '920 Queen St E',
#   320),
#  ('Regal Rd / Dufferin St',
#   43.673939,
#   -79.441159,
#   1,
#   17,
#   'Rush Hour',
#   4.5,
#   '1438A Dufferin Street',
#   321),
#  ('Regal Rd / Dufferin St',
#   43.673939,
#   -79.441159,
#   1,
#   17,
#   'Agio',
#   4.5,
#   '1351 St Clair Avenue W',
#   322),
#  ('Regal Rd / Dufferin St',
#   43.673939,
#   -79.441159,
#   1,
#   17,
#   'The Sovereign',
#   4.5,
#   '1359 Davenport Road',
#   323),
#  ('Regal Rd / Dufferin St',
#   43.673939,
#   -79.441159,
#   1,
#   17,
#   'CANO Restaurant',
#   4.5,
#   '1108 St Clair Avenue W',
#   324),
#  ('Regal Rd / Dufferin St',
#   43.673939,
#   -79.441159,
#   1,
#   17,
#   'Nodo Restaurant',
#   4.5,
#   '794 Saint Clair Avenue W',
#   325),
#  ('Regal Rd / Dufferin St',
#   43.673939,
#   -79.441159,
#   1,
#   17,
#   'Pukka',
#   4.0,
#   '778 St. Clair Avenue W',
#   326),
#  ('Regal Rd / Dufferin St',
#   43.673939,
#   -79.441159,
#   1,
#   17,
#   'Marcello’s pizzeria',
#   4.0,
#   '1163 Saint Clair Avenue W',
#   327),
#  ('Regal Rd / Dufferin St',
#   43.673939,
#   -79.441159,
#   1,
#   17,
#   'Barista & Chef',
#   4.5,
#   '1006 Saint Clair Avenue W',
#   328),
#  ('Regal Rd / Dufferin St',
#   43.673939,
#   -79.441159,
#   1,
#   17,
#   "Emma's Country Kitchen",
#   4.0,
#   '810 Saint Clair Avenue W',
#   329),
#  ('Regal Rd / Dufferin St',
#   43.673939,
#   -79.441159,
#   1,
#   17,
#   'Famiglia Baldassarre',
#   4.5,
#   '122 Geary Avenue',
#   330),
#  ('Regal Rd / Dufferin St',
#   43.673939,
#   -79.441159,
#   1,
#   17,
#   'Pizza e Pazzi',
#   4.0,
#   '1182 St Clair Avenue W',
#   331),
#  ('Regal Rd / Dufferin St',
#   43.673939,
#   -79.441159,
#   1,
#   17,
#   'Rio 40 Restaurant',
#   4.0,
#   '1256 Saint Clair Avenue West',
#   332),
#  ('Regal Rd / Dufferin St',
#   43.673939,
#   -79.441159,
#   1,
#   17,
#   'FK',
#   4.5,
#   '770 St Clair Avenue W',
#   333),
#  ('Regal Rd / Dufferin St',
#   43.673939,
#   -79.441159,
#   1,
#   17,
#   'Atomic 10',
#   4.5,
#   '145 Lauder Ave',
#   334),
#  ('Regal Rd / Dufferin St',
#   43.673939,
#   -79.441159,
#   1,
#   17,
#   'Aviv Immigrant Kitchen',
#   4.5,
#   '779 St. Clair Avenue W',
#   335),
#  ('Regal Rd / Dufferin St',
#   43.673939,
#   -79.441159,
#   1,
#   17,
#   'Good Behaviour',
#   4.5,
#   '342 Westmoreland Avenue N',
#   336),
#  ('Regal Rd / Dufferin St',
#   43.673939,
#   -79.441159,
#   1,
#   17,
#   'DeSotos Eatery',
#   4.0,
#   '1079 St Clair Avenue West',
#   337),
#  ('Regal Rd / Dufferin St',
#   43.673939,
#   -79.441159,
#   1,
#   17,
#   'Tre Mari Bakery',
#   4.5,
#   '1311 Saint Clair Avenue W',
#   338),
#  ('Regal Rd / Dufferin St',
#   43.673939,
#   -79.441159,
#   1,
#   17,
#   "King's Tacos",
#   4.0,
#   '1190 St Clair Avenue W',
#   339),
#  ('Regal Rd / Dufferin St',
#   43.673939,
#   -79.441159,
#   1,
#   17,
#   'Parallel',
#   4.0,
#   '217 Geary Avenue',
#   340),
#  ('Morse St / Eastern Ave',
#   43.657991,
#   -79.340075,
#   5,
#   18,
#   'Descendant Detroit Style Pizza',
#   4.5,
#   '1168 Queen Street E',
#   341),
#  ('Morse St / Eastern Ave',
#   43.657991,
#   -79.340075,
#   5,
#   18,
#   'Eastside Social',
#   4.5,
#   '1008 Queen Street E',
#   342),
#  ('Morse St / Eastern Ave',
#   43.657991,
#   -79.340075,
#   5,
#   18,
#   'EAT BKK Thai Kitchen',
#   4.0,
#   '898 Queen Street E',
#   343),
#  ('Morse St / Eastern Ave',
#   43.657991,
#   -79.340075,
#   5,
#   18,
#   'Ascari',
#   4.0,
#   '1111 Queen Street E',
#   344),
#  ('Morse St / Eastern Ave',
#   43.657991,
#   -79.340075,
#   5,
#   18,
#   'Leslieville Pumps',
#   4.0,
#   '913 Queen Street E',
#   345),
#  ('Morse St / Eastern Ave',
#   43.657991,
#   -79.340075,
#   5,
#   18,
#   'Barrio Cerveceria',
#   3.0,
#   '884 Queen Street E',
#   346),
#  ('Morse St / Eastern Ave',
#   43.657991,
#   -79.340075,
#   5,
#   18,
#   'Tabule Middle Eastern Cuisine',
#   4.0,
#   '810 Queen Street  E',
#   347),
#  ('Morse St / Eastern Ave',
#   43.657991,
#   -79.340075,
#   5,
#   18,
#   "Ed's Real Scoop",
#   4.5,
#   '920 Queen St E',
#   348),
#  ('Morse St / Eastern Ave',
#   43.657991,
#   -79.340075,
#   5,
#   18,
#   'Baldini Restaurant',
#   3.5,
#   '1012 Queen Street E',
#   349),
#  ('Morse St / Eastern Ave',
#   43.657991,
#   -79.340075,
#   5,
#   18,
#   'The Comrade',
#   4.0,
#   '758 Queen Street E',
#   350),
#  ('Morse St / Eastern Ave',
#   43.657991,
#   -79.340075,
#   5,
#   18,
#   'White Lily Diner',
#   4.5,
#   '678 Queen Street E',
#   351),
#  ('Morse St / Eastern Ave',
#   43.657991,
#   -79.340075,
#   5,
#   18,
#   'Purple Penguin Cafe',
#   4.0,
#   '889 Queen Street E',
#   352),
#  ('Morse St / Eastern Ave',
#   43.657991,
#   -79.340075,
#   5,
#   18,
#   'Wynona',
#   4.5,
#   '819 Gerrard Street E',
#   353),
#  ('Morse St / Eastern Ave',
#   43.657991,
#   -79.340075,
#   5,
#   18,
#   'Radical Road Brewing',
#   4.5,
#   '1177 Queen Street E',
#   354),
#  ('Morse St / Eastern Ave',
#   43.657991,
#   -79.340075,
#   5,
#   18,
#   'Goods & Provisions',
#   4.0,
#   '1124 Queen Street E',
#   355),
#  ('Morse St / Eastern Ave',
#   43.657991,
#   -79.340075,
#   5,
#   18,
#   'Batifole Restaurant',
#   4.0,
#   '744 Gerrard Street E',
#   356),
#  ('Morse St / Eastern Ave',
#   43.657991,
#   -79.340075,
#   5,
#   18,
#   'CrowdedHouse',
#   4.5,
#   '1161 Queen Street E',
#   357),
#  ('Morse St / Eastern Ave',
#   43.657991,
#   -79.340075,
#   5,
#   18,
#   'Leslie Jones',
#   4.0,
#   '1182 Queen Street E',
#   358),
#  ('Morse St / Eastern Ave',
#   43.657991,
#   -79.340075,
#   5,
#   18,
#   'The Roy Public House',
#   3.5,
#   '894 Queen Street E',
#   359),
#  ('Morse St / Eastern Ave',
#   43.657991,
#   -79.340075,
#   5,
#   18,
#   "Frankie's",
#   4.0,
#   '892 Queen Street E',
#   360),
#  ('Alton Ave / Dundas St E (Greenwood Park)',
#   43.66745,
#   -79.329408,
#   13,
#   19,
#   'Descendant Detroit Style Pizza',
#   4.5,
#   '1168 Queen Street E',
#   361),
#  ('Alton Ave / Dundas St E (Greenwood Park)',
#   43.66745,
#   -79.329408,
#   13,
#   19,
#   'Lake Inez',
#   4.5,
#   '1471 Gerrard Street E',
#   362),
#  ('Alton Ave / Dundas St E (Greenwood Park)',
#   43.66745,
#   -79.329408,
#   13,
#   19,
#   'Blondies',
#   4.0,
#   '1555 Dundas Street E',
#   363),
#  ('Alton Ave / Dundas St E (Greenwood Park)',
#   43.66745,
#   -79.329408,
#   13,
#   19,
#   'Ascari',
#   4.0,
#   '1111 Queen Street E',
#   364),
#  ('Alton Ave / Dundas St E (Greenwood Park)',
#   43.66745,
#   -79.329408,
#   13,
#   19,
#   'Chula Taberna Mexicana',
#   4.0,
#   '1058 Gerrard Street E',
#   365),
#  ('Alton Ave / Dundas St E (Greenwood Park)',
#   43.66745,
#   -79.329408,
#   13,
#   19,
#   "Maha's",
#   4.0,
#   '226 Greenwood Avenue',
#   366),
#  ('Alton Ave / Dundas St E (Greenwood Park)',
#   43.66745,
#   -79.329408,
#   13,
#   19,
#   'Leslie Jones',
#   4.0,
#   '1182 Queen Street E',
#   367),
#  ('Alton Ave / Dundas St E (Greenwood Park)',
#   43.66745,
#   -79.329408,
#   13,
#   19,
#   'Tea N Bannock',
#   4.5,
#   '1294 Gerrard Street E',
#   368),
#  ('Alton Ave / Dundas St E (Greenwood Park)',
#   43.66745,
#   -79.329408,
#   13,
#   19,
#   'Radical Road Brewing',
#   4.5,
# ...
#   43.640114,
#   -79.393249,
#   15,
#   45,
#   "Rodney's Oyster House",
#   4.0,
#   '469 King Street W',
#   883),
#  ('Spadina Ave / Fort York Blvd',
#   43.640114,
#   -79.393249,
#   15,
#   45,
#   'Gusto 101',
#   4.0,
#   '101 Portland Street',
#   884),
#  ('Spadina Ave / Fort York Blvd',
#   43.640114,
#   -79.393249,
#   15,
#   45,
#   'Mira',
#   4.5,
#   '420A Wellington Street W',
#   885),
#  ('Spadina Ave / Fort York Blvd',
#   43.640114,
#   -79.393249,
#   15,
#   45,
#   'Hunters Landing',
#   3.5,
#   '82 Fort York Blvd',
#   886),
#  ('Spadina Ave / Fort York Blvd',
#   43.640114,
#   -79.393249,
#   15,
#   45,
#   'Le Sélect Bistro',
#   4.0,
#   '432 Wellington Street W',
#   887),
#  ('Spadina Ave / Fort York Blvd',
#   43.640114,
#   -79.393249,
#   15,
#   45,
#   'Akira Back',
#   4.0,
#   '80 Blue Jays Way',
#   888),
#  ('Spadina Ave / Fort York Blvd',
#   43.640114,
#   -79.393249,
#   15,
#   45,
#   'Alo Restaurant',
#   4.5,
#   '163 Spadina Avenue',
#   889),
#  ('Spadina Ave / Fort York Blvd',
#   43.640114,
#   -79.393249,
#   15,
#   45,
#   'Jacobs & Co. Steakhouse',
#   4.5,
#   '12 Brant Street',
#   890),
#  ('Spadina Ave / Fort York Blvd',
#   43.640114,
#   -79.393249,
#   15,
#   45,
#   'Khao San Road',
#   4.0,
#   '11 Charlotte Street',
#   891),
#  ('Spadina Ave / Fort York Blvd',
#   43.640114,
#   -79.393249,
#   15,
#   45,
#   'Lee',
#   4.0,
#   '497 Richmond Street W',
#   892),
#  ('Spadina Ave / Fort York Blvd',
#   43.640114,
#   -79.393249,
#   15,
#   45,
#   'Buca',
#   4.0,
#   '604 King Street W',
#   893),
#  ('Spadina Ave / Fort York Blvd',
#   43.640114,
#   -79.393249,
#   15,
#   45,
#   'Aloette',
#   4.5,
#   '163 Spadina Avenue',
#   894),
#  ('Spadina Ave / Fort York Blvd',
#   43.640114,
#   -79.393249,
#   15,
#   45,
#   "Chubby's Jamaican Kitchen",
#   4.0,
#   '104 Portland Street',
#   895),
#  ('Spadina Ave / Fort York Blvd',
#   43.640114,
#   -79.393249,
#   15,
#   45,
#   'Chin Chin Street Side Kitchen',
#   3.5,
#   '363 Bremner Boulevard',
#   896),
#  ('Spadina Ave / Fort York Blvd',
#   43.640114,
#   -79.393249,
#   15,
#   45,
#   'Wvrst',
#   4.0,
#   '609 King Street W',
#   897),
#  ('Spadina Ave / Fort York Blvd',
#   43.640114,
#   -79.393249,
#   15,
#   45,
#   'The Haam',
#   4.0,
#   '342 Adelaide St W',
#   898),
#  ('Spadina Ave / Fort York Blvd',
#   43.640114,
#   -79.393249,
#   15,
#   45,
#   'The Morning After',
#   3.5,
#   '88 Fort York Boulevard',
#   899),
#  ('Spadina Ave / Fort York Blvd',
#   43.640114,
#   -79.393249,
#   15,
#   45,
#   '360 Restaurant',
#   3.5,
#   'CN Tower',
#   900),
#  ('Augusta Ave / Denison Sq',
#   43.653766,
#   -79.4016759,
#   6,
#   46,
#   'Grey Gardens',
#   4.5,
#   '199 Augusta Avenue',
#   901),
#  ('Augusta Ave / Denison Sq',
#   43.653766,
#   -79.4016759,
#   6,
#   46,
#   'Saigon Lotus',
#   4.5,
#   '6 St Andrew Street',
#   902),
#  ('Augusta Ave / Denison Sq',
#   43.653766,
#   -79.4016759,
#   6,
#   46,
#   'Seven Lives Tacos y Mariscos',
#   4.5,
#   '72 Kensington Avenue',
#   903),
#  ('Augusta Ave / Denison Sq',
#   43.653766,
#   -79.4016759,
#   6,
#   46,
#   'Fudao noodle house',
#   4.0,
#   '358 Spadina ave',
#   904),
#  ('Augusta Ave / Denison Sq',
#   43.653766,
#   -79.4016759,
#   6,
#   46,
#   'The Cottage Cheese',
#   4.5,
#   '64 Oxford Street',
#   905),
#  ('Augusta Ave / Denison Sq',
#   43.653766,
#   -79.4016759,
#   6,
#   46,
#   'The Burgernator',
#   4.0,
#   '269 Augusta Avenue',
#   906),
#  ('Augusta Ave / Denison Sq',
#   43.653766,
#   -79.4016759,
#   6,
#   46,
#   'Pizzeria Via Mercanti',
#   3.5,
#   '188 Augusta Avenue',
#   907),
#  ('Augusta Ave / Denison Sq',
#   43.653766,
#   -79.4016759,
#   6,
#   46,
#   'Rikki Tikki',
#   5.0,
#   '209 Augusta Avenue',
#   908),
#  ('Augusta Ave / Denison Sq',
#   43.653766,
#   -79.4016759,
#   6,
#   46,
#   'Top Gun Burgers',
#   3.5,
#   '251 Augusta Avenue',
#   909),
#  ('Augusta Ave / Denison Sq',
#   43.653766,
#   -79.4016759,
#   6,
#   46,
#   'Juicy Dumpling',
#   4.0,
#   '280 Spadina Ave',
#   910),
#  ('Augusta Ave / Denison Sq',
#   43.653766,
#   -79.4016759,
#   6,
#   46,
#   'Belgian Sweet Corner - Lekker',
#   4.5,
#   '237 Augusta Avenue',
#   911),
#  ('Augusta Ave / Denison Sq',
#   43.653766,
#   -79.4016759,
#   6,
#   46,
#   'Ajisen Ramen',
#   3.5,
#   '332 Spadina Avenue',
#   912),
#  ('Augusta Ave / Denison Sq',
#   43.653766,
#   -79.4016759,
#   6,
#   46,
#   'Chine Legendary Hot Pot & Noodles',
#   4.0,
#   '327 Spadina Avenue',
#   913),
#  ('Augusta Ave / Denison Sq',
#   43.653766,
#   -79.4016759,
#   6,
#   46,
#   "Fresco's Fish & Chips",
#   4.5,
#   '201 Augusta Avenue',
#   914),
#  ('Augusta Ave / Denison Sq',
#   43.653766,
#   -79.4016759,
#   6,
#   46,
#   'Film Cafe by Eative',
#   3.5,
#   '230 Augusta Avenue',
#   915),
#  ('Augusta Ave / Denison Sq',
#   43.653766,
#   -79.4016759,
#   6,
#   46,
#   'Alo Restaurant',
#   4.5,
#   '163 Spadina Avenue',
#   916),
#  ('Augusta Ave / Denison Sq',
#   43.653766,
#   -79.4016759,
#   6,
#   46,
#   'Bar Raval',
#   4.0,
#   '505 College Street',
#   917),
#  ('Augusta Ave / Denison Sq',
#   43.653766,
#   -79.4016759,
#   6,
#   46,
#   'Aloette',
#   4.5,
#   '163 Spadina Avenue',
#   918),
#  ('Augusta Ave / Denison Sq',
#   43.653766,
#   -79.4016759,
#   6,
#   46,
#   'Shi Miaodao Yunnan Rice Noodle',
#   4.0,
#   '318 Spadina Avenue',
#   919),
#  ('Augusta Ave / Denison Sq',
#   43.653766,
#   -79.4016759,
#   6,
#   46,
#   "Otto's Berlin Döner",
#   4.0,
#   '256 Augusta Avenue',
#   920),
#  ('Lansdowne Ave / Whytock Ave',
#   43.6538888888889,
#   -79.4413888888889,
#   2,
#   47,
#   'Sugo',
#   4.5,
#   '1281 Bloor Street W',
#   921),
#  ('Lansdowne Ave / Whytock Ave',
#   43.6538888888889,
#   -79.4413888888889,
#   2,
#   47,
#   'Antler Kitchen & Bar',
#   4.5,
#   '1454 Dundas Street West',
#   922),
#  ('Lansdowne Ave / Whytock Ave',
#   43.6538888888889,
#   -79.4413888888889,
#   2,
#   47,
#   'Le Baratin',
#   4.5,
#   '1600 Dundas Street. W',
#   923),
#  ('Lansdowne Ave / Whytock Ave',
#   43.6538888888889,
#   -79.4413888888889,
#   2,
#   47,
#   'Café Polonez',
#   4.5,
#   '195 Roncesvalles Avenue',
#   924),
#  ('Lansdowne Ave / Whytock Ave',
#   43.6538888888889,
#   -79.4413888888889,
#   2,
#   47,
#   'Barque Smokehouse',
#   4.0,
#   '299 Roncesvalles Avenue',
#   925),
#  ('Lansdowne Ave / Whytock Ave',
#   43.6538888888889,
#   -79.4413888888889,
#   2,
#   47,
#   'Good Fork',
#   4.0,
#   '1550 Dundas Street W',
#   926),
#  ('Lansdowne Ave / Whytock Ave',
#   43.6538888888889,
#   -79.4413888888889,
#   2,
#   47,
#   'The Commoner',
#   4.0,
#   '2067 Dundas Street W',
#   927),
#  ('Lansdowne Ave / Whytock Ave',
#   43.6538888888889,
#   -79.4413888888889,
#   2,
#   47,
#   'The Ace',
#   4.0,
#   '231A Roncesvalles Avenue',
#   928),
#  ('Lansdowne Ave / Whytock Ave',
#   43.6538888888889,
#   -79.4413888888889,
#   2,
#   47,
#   'Pho Linh',
#   4.0,
#   '1156 College Street W',
#   929),
#  ('Lansdowne Ave / Whytock Ave',
#   43.6538888888889,
#   -79.4413888888889,
#   2,
#   47,
#   'Takht-e Tavoos',
#   4.5,
#   '1120 College Street',
#   930),
#  ('Lansdowne Ave / Whytock Ave',
#   43.6538888888889,
#   -79.4413888888889,
#   2,
#   47,
#   'Pizzeria Defina',
#   4.0,
#   '321 Roncesvalles Ave',
#   931),
#  ('Lansdowne Ave / Whytock Ave',
#   43.6538888888889,
#   -79.4413888888889,
#   2,
#   47,
#   'The Federal',
#   4.0,
#   '1438 Dundas Street W',
#   932),
#  ('Lansdowne Ave / Whytock Ave',
#   43.6538888888889,
#   -79.4413888888889,
#   2,
#   47,
#   'La Cubana',
#   3.5,
#   '392 Roncesvalles Avenue',
#   933),
#  ('Lansdowne Ave / Whytock Ave',
#   43.6538888888889,
#   -79.4413888888889,
#   2,
#   47,
#   'Bar Neon',
#   4.0,
#   '1226 Bloor Street W',
#   934),
#  ('Lansdowne Ave / Whytock Ave',
#   43.6538888888889,
#   -79.4413888888889,
#   2,
#   47,
#   'Brazil Bakery and Pastry',
#   4.0,
#   '1566 Dundas Street W',
#   935),
#  ('Lansdowne Ave / Whytock Ave',
#   43.6538888888889,
#   -79.4413888888889,
#   2,
#   47,
#   'Burdock',
#   3.5,
#   '1184 Bloor Street W',
#   936),
#  ('Lansdowne Ave / Whytock Ave',
#   43.6538888888889,
#   -79.4413888888889,
#   2,
#   47,
#   'African Palace',
#   4.0,
#   '977 Bloor Street W',
#   937),
#  ('Lansdowne Ave / Whytock Ave',
#   43.6538888888889,
#   -79.4413888888889,
#   2,
#   47,
#   'Viaggio',
#   4.0,
#   '1727 Dundas St W',
#   938),
#  ('Lansdowne Ave / Whytock Ave',
#   43.6538888888889,
#   -79.4413888888889,
#   2,
#   47,
#   'Wenona Craft Beer Lodge',
#   4.0,
#   '1069 Bloor Street W',
#   939),
#  ('Lansdowne Ave / Whytock Ave',
#   43.6538888888889,
#   -79.4413888888889,
#   2,
#   47,
#   'The Gaslight',
#   4.5,
#   '1426 Bloor Street W',
#   940),
#  ('Sterling Rd / Dundas St W',
#   43.6508333333333,
#   -79.4430555555556,
#   0,
#   48,
#   'Le Baratin',
#   4.5,
#   '1600 Dundas Street. W',
#   941),
#  ('Sterling Rd / Dundas St W',
#   43.6508333333333,
#   -79.4430555555556,
#   0,
#   48,
#   'Café Polonez',
#   4.5,
#   '195 Roncesvalles Avenue',
#   942),
#  ('Sterling Rd / Dundas St W',
#   43.6508333333333,
#   -79.4430555555556,
#   0,
#   48,
#   'Sugo',
#   4.5,
#   '1281 Bloor Street W',
#   943),
#  ('Sterling Rd / Dundas St W',
#   43.6508333333333,
#   -79.4430555555556,
#   0,
#   48,
#   'The Commoner',
#   4.0,
#   '2067 Dundas Street W',
#   944),
#  ('Sterling Rd / Dundas St W',
#   43.6508333333333,
#   -79.4430555555556,
#   0,
#   48,
#   'Barque Smokehouse',
#   4.0,
#   '299 Roncesvalles Avenue',
#   945),
#  ('Sterling Rd / Dundas St W',
#   43.6508333333333,
#   -79.4430555555556,
#   0,
#   48,
#   'Guu Izakaya Toronto',
#   4.0,
#   '1314 Queen Street W',
#   946),
#  ('Sterling Rd / Dundas St W',
#   43.6508333333333,
#   -79.4430555555556,
#   0,
#   48,
#   'Good Fork',
#   4.0,
#   '1550 Dundas Street W',
#   947),
#  ('Sterling Rd / Dundas St W',
#   43.6508333333333,
#   -79.4430555555556,
#   0,
#   48,
#   'Viaggio',
#   4.0,
#   '1727 Dundas St W',
#   948),
#  ('Sterling Rd / Dundas St W',
#   43.6508333333333,
#   -79.4430555555556,
#   0,
#   48,
#   'The Ace',
#   4.0,
#   '231A Roncesvalles Avenue',
#   949),
#  ('Sterling Rd / Dundas St W',
#   43.6508333333333,
#   -79.4430555555556,
#   0,
#   48,
#   'Pizzeria Defina',
#   4.0,
#   '321 Roncesvalles Ave',
#   950),
#  ('Sterling Rd / Dundas St W',
#   43.6508333333333,
#   -79.4430555555556,
#   0,
#   48,
#   'Takht-e Tavoos',
#   4.5,
#   '1120 College Street',
#   951),
#  ('Sterling Rd / Dundas St W',
#   43.6508333333333,
#   -79.4430555555556,
#   0,
#   48,
#   'Pho Linh',
#   4.0,
#   '1156 College Street W',
#   952),
#  ('Sterling Rd / Dundas St W',
#   43.6508333333333,
#   -79.4430555555556,
#   0,
#   48,
#   "Peter's No Frills",
#   4.0,
#   '222 Lansdowne Avenue',
#   953),
#  ('Sterling Rd / Dundas St W',
#   43.6508333333333,
#   -79.4430555555556,
#   0,
#   48,
#   'La Cubana',
#   3.5,
#   '392 Roncesvalles Avenue',
#   954),
#  ('Sterling Rd / Dundas St W',
#   43.6508333333333,
#   -79.4430555555556,
#   0,
#   48,
#   'Brazil Bakery and Pastry',
#   4.0,
#   '1566 Dundas Street W',
#   955),
#  ('Sterling Rd / Dundas St W',
#   43.6508333333333,
#   -79.4430555555556,
#   0,
#   48,
#   'Dil Se Indian Restaurant & Bar',
#   4.5,
#   '335 Roncesvalles Avenue',
#   956),
#  ('Sterling Rd / Dundas St W',
#   43.6508333333333,
#   -79.4430555555556,
#   0,
#   48,
#   'Burdock',
#   3.5,
#   '1184 Bloor Street W',
#   957),
#  ('Sterling Rd / Dundas St W',
#   43.6508333333333,
#   -79.4430555555556,
#   0,
#   48,
#   'Bar Neon',
#   4.0,
#   '1226 Bloor Street W',
#   958),
#  ('Sterling Rd / Dundas St W',
#   43.6508333333333,
#   -79.4430555555556,
#   0,
#   48,
#   'The Gaslight',
#   4.5,
#   '1426 Bloor Street W',
#   959),
#  ('Sterling Rd / Dundas St W',
#   43.6508333333333,
#   -79.4430555555556,
#   0,
#   48,
#   'Arabesque Middle Eastern Foods',
#   4.5,
#   '1068 College Street',
#   960),
#  ('St Clarens Ave / College St',
#   43.651238,
#   -79.43868,
#   1,
#   49,
#   'Le Baratin',
#   4.5,
#   '1600 Dundas Street. W',
#   961),
#  ('St Clarens Ave / College St',
#   43.651238,
#   -79.43868,
#   1,
#   49,
#   'Antler Kitchen & Bar',
#   4.5,
#   '1454 Dundas Street West',
#   962),
#  ('St Clarens Ave / College St',
#   43.651238,
#   -79.43868,
#   1,
#   49,
#   'Café Polonez',
#   4.5,
#   '195 Roncesvalles Avenue',
#   963),
#  ('St Clarens Ave / College St',
#   43.651238,
#   -79.43868,
#   1,
#   49,
#   'Sugo',
#   4.5,
#   '1281 Bloor Street W',
#   964),
#  ('St Clarens Ave / College St',
#   43.651238,
#   -79.43868,
#   1,
#   49,
#   'Viaggio',
#   4.0,
#   '1727 Dundas St W',
#   965),
#  ('St Clarens Ave / College St',
#   43.651238,
#   -79.43868,
#   1,
#   49,
#   'Good Fork',
#   4.0,
#   '1550 Dundas Street W',
#   966),
#  ('St Clarens Ave / College St',
#   43.651238,
#   -79.43868,
#   1,
#   49,
#   'Barque Smokehouse',
#   4.0,
#   '299 Roncesvalles Avenue',
#   967),
#  ('St Clarens Ave / College St',
#   43.651238,
#   -79.43868,
#   1,
#   49,
#   'Giulietta',
#   4.0,
#   '972 College Street',
#   968),
#  ('St Clarens Ave / College St',
#   43.651238,
#   -79.43868,
#   1,
#   49,
#   'Pho Linh',
#   4.0,
#   '1156 College Street W',
#   969),
#  ('St Clarens Ave / College St',
#   43.651238,
#   -79.43868,
#   1,
#   49,
#   'Takht-e Tavoos',
#   4.5,
#   '1120 College Street',
#   970),
#  ('St Clarens Ave / College St',
#   43.651238,
#   -79.43868,
#   1,
#   49,
#   'Brazil Bakery and Pastry',
#   4.0,
#   '1566 Dundas Street W',
#   971),
#  ('St Clarens Ave / College St',
#   43.651238,
#   -79.43868,
#   1,
#   49,
#   'Imanishi Japanese Kitchen',
#   4.0,
#   '1330 Dundas Street W',
#   972),
#  ('St Clarens Ave / College St',
#   43.651238,
#   -79.43868,
#   1,
#   49,
#   'Lula Lounge',
#   3.5,
#   '1585 Dundas Street W',
#   973),
#  ('St Clarens Ave / College St',
#   43.651238,
#   -79.43868,
#   1,
#   49,
#   'The Ace',
#   4.0,
#   '231A Roncesvalles Avenue',
#   974),
#  ('St Clarens Ave / College St',
#   43.651238,
#   -79.43868,
#   1,
#   49,
#   'The Commoner',
#   4.0,
#   '2067 Dundas Street W',
#   975),
#  ('St Clarens Ave / College St',
#   43.651238,
#   -79.43868,
#   1,
#   49,
#   'Pizzeria Defina',
#   4.0,
#   '321 Roncesvalles Ave',
#   976),
#  ('St Clarens Ave / College St',
#   43.651238,
#   -79.43868,
#   1,
#   49,
#   'The Federal',
#   4.0,
#   '1438 Dundas Street W',
#   977),
#  ('St Clarens Ave / College St',
#   43.651238,
#   -79.43868,
#   1,
#   49,
#   "Peter's No Frills",
#   4.0,
#   '222 Lansdowne Avenue',
#   978),
#  ('St Clarens Ave / College St',
#   43.651238,
#   -79.43868,
#   1,
#   49,
#   'La Cubana',
#   3.5,
#   '392 Roncesvalles Avenue',
#   979),
#  ('St Clarens Ave / College St',
#   43.651238,
#   -79.43868,
#   1,
#   49,
#   'Burdock',
#   3.5,
#   '1184 Bloor Street W',
#   980),
#  ('Ossington Ave / College St',
#   43.6544915,
#   -79.422634,
#   2,
#   50,
#   'Bar Isabel',
#   4.0,
#   '797 College Street',
#   981),
#  ('Ossington Ave / College St',
#   43.6544915,
#   -79.422634,
#   2,
#   50,
#   'The Caledonian',
#   4.5,
#   '856 College Street',
#   982),
#  ('Ossington Ave / College St',
#   43.6544915,
#   -79.422634,
#   2,
#   50,
#   'Chiado',
#   4.0,
#   '864 College Street',
#   983),
#  ('Ossington Ave / College St',
#   43.6544915,
#   -79.422634,
#   2,
#   50,
#   'Giulietta',
#   4.0,
#   '972 College Street',
#   984),
#  ('Ossington Ave / College St',
#   43.6544915,
#   -79.422634,
#   2,
#   50,
#   'Antler Kitchen & Bar',
#   4.5,
#   '1454 Dundas Street West',
#   985),
#  ('Ossington Ave / College St',
#   43.6544915,
#   -79.422634,
#   2,
#   50,
#   'Imm Thai Kitchen',
#   4.5,
#   '651 College Street',
#   986),
#  ('Ossington Ave / College St',
#   43.6544915,
#   -79.422634,
#   2,
#   50,
#   'La Banane',
#   4.5,
#   '227 Ossington Avenue',
#   987),
#  ('Ossington Ave / College St',
#   43.6544915,
#   -79.422634,
#   2,
#   50,
#   'Regina Pizzeria & Trattoria',
#   4.0,
#   '782 College Street',
#   988),
#  ('Ossington Ave / College St',
#   43.6544915,
#   -79.422634,
#   2,
#   50,
#   'Vos Restaurante Argentino',
#   4.0,
#   '847 College st',
#   989),
#  ('Ossington Ave / College St',
#   43.6544915,
#   -79.422634,
#   2,
#   50,
#   'Bellwoods Brewery',
#   4.0,
#   '124-126 Ossington Avenue',
#   990),
#  ('Ossington Ave / College St',
#   43.6544915,
#   -79.422634,
#   2,
#   50,
#   'Pizzeria Libretto',
#   4.0,
#   '221 Ossington Avenue',
#   991),
#  ('Ossington Ave / College St',
#   43.6544915,
#   -79.422634,
#   2,
#   50,
#   'College Falafel',
#   4.0,
#   '450 Ossington Ave',
#   992),
#  ('Ossington Ave / College St',
#   43.6544915,
#   -79.422634,
#   2,
#   50,
#   'Mamakas Taverna',
#   4.0,
#   '80 Ossington Avenue',
#   993),
#  ('Ossington Ave / College St',
#   43.6544915,
#   -79.422634,
#   2,
#   50,
#   'Enoteca Sociale',
#   4.0,
#   '1288 Dundas St W',
#   994),
#  ('Ossington Ave / College St',
#   43.6544915,
#   -79.422634,
#   2,
#   50,
#   'Union',
#   4.0,
#   '72A Ossington Avenue',
#   995),
#  ('Ossington Ave / College St',
#   43.6544915,
#   -79.422634,
#   2,
#   50,
#   'The Night Baker',
#   4.0,
#   '825 College Street',
#   996),
#  ('Ossington Ave / College St',
#   43.6544915,
#   -79.422634,
#   2,
#   50,
#   'The Daily Dumpling Wonton Co',
#   4.0,
#   '792 College St',
#   997),
#  ('Ossington Ave / College St',
#   43.6544915,
#   -79.422634,
#   2,
#   50,
#   'Taverniti',
#   4.0,
#   '591 College Street',
#   998),
#  ('Ossington Ave / College St',
#   43.6544915,
#   -79.422634,
#   2,
#   50,
#   'La Bella Managua',
#   4.5,
#   '872 Bloor Street W',
#   999),
#  ('Ossington Ave / College St',
#   43.6544915,
#   -79.422634,
#   2,
#   50,
#   'Imanishi Japanese Kitchen',
#   4.0,
#   '1330 Dundas Street W',
#   1000)]

# %%
#Converting results into a dataframe
sqlite_df = pd.DataFrame(data, columns = ['station_address','latitude','longitude','free_bikes','ID','place_name','rating','place_address','result_ID'])

# %%
sqlite_df
# Out:
#                 station_address   latitude  longitude  free_bikes  ID  \
# 0     Queen St E / Woodward Ave  43.665269 -79.319796          14   1
# 1     Queen St E / Woodward Ave  43.665269 -79.319796          14   1
# 2     Queen St E / Woodward Ave  43.665269 -79.319796          14   1
# 3     Queen St E / Woodward Ave  43.665269 -79.319796          14   1
# 4     Queen St E / Woodward Ave  43.665269 -79.319796          14   1
# ..                          ...        ...        ...         ...  ..
# 995  Ossington Ave / College St  43.654491 -79.422634           2  50
# 996  Ossington Ave / College St  43.654491 -79.422634           2  50
# 997  Ossington Ave / College St  43.654491 -79.422634           2  50
# 998  Ossington Ave / College St  43.654491 -79.422634           2  50
# 999  Ossington Ave / College St  43.654491 -79.422634           2  50
#
#                        place_name  rating          place_address  result_ID
# 0                         O Sushi     4.0       6 Coxwell Avenue          1
# 1                       Lake Inez     4.5  1471 Gerrard Street E          2
# 2             The Burger's Priest     3.5    1636 Queen Street E          3
# 3                        Jaclyn's     4.5    1588 Queen Street E          4
# 4                Burrito Bandidos     3.5    1614 Queen Street E          5
# ..                            ...     ...                    ...        ...
# 995               The Night Baker     4.0     825 College Street        996
# 996  The Daily Dumpling Wonton Co     4.0         792 College St        997
# 997                     Taverniti     4.0     591 College Street        998
# 998              La Bella Managua     4.5     872 Bloor Street W        999
# 999     Imanishi Japanese Kitchen     4.0   1330 Dundas Street W       1000
#
# [1000 rows x 9 columns]

# %% [markdown]
# Look at the data before and after the join to validate your data.

# %%
#Viewing data after the join
sqlite_df
# Out:
#                 station_address   latitude  longitude  free_bikes  ID  \
# 0     Queen St E / Woodward Ave  43.665269 -79.319796          14   1
# 1     Queen St E / Woodward Ave  43.665269 -79.319796          14   1
# 2     Queen St E / Woodward Ave  43.665269 -79.319796          14   1
# 3     Queen St E / Woodward Ave  43.665269 -79.319796          14   1
# 4     Queen St E / Woodward Ave  43.665269 -79.319796          14   1
# ..                          ...        ...        ...         ...  ..
# 995  Ossington Ave / College St  43.654491 -79.422634           2  50
# 996  Ossington Ave / College St  43.654491 -79.422634           2  50
# 997  Ossington Ave / College St  43.654491 -79.422634           2  50
# 998  Ossington Ave / College St  43.654491 -79.422634           2  50
# 999  Ossington Ave / College St  43.654491 -79.422634           2  50
#
#                        place_name  rating          place_address  result_ID
# 0                         O Sushi     4.0       6 Coxwell Avenue          1
# 1                       Lake Inez     4.5  1471 Gerrard Street E          2
# 2             The Burger's Priest     3.5    1636 Queen Street E          3
# 3                        Jaclyn's     4.5    1588 Queen Street E          4
# 4                Burrito Bandidos     3.5    1614 Queen Street E          5
# ..                            ...     ...                    ...        ...
# 995               The Night Baker     4.0     825 College Street        996
# 996  The Daily Dumpling Wonton Co     4.0         792 College St        997
# 997                     Taverniti     4.0     591 College Street        998
# 998              La Bella Managua     4.5     872 Bloor Street W        999
# 999     Imanishi Japanese Kitchen     4.0   1330 Dundas Street W       1000
#
# [1000 rows x 9 columns]

# %%
#Viewing data before the join
merged_tables
# Out:
#                 station_address   latitude  longitude  free_bikes  ID  \
# 0     Queen St E / Woodward Ave  43.665269 -79.319796          14   1
# 1     Queen St E / Woodward Ave  43.665269 -79.319796          14   1
# 2     Queen St E / Woodward Ave  43.665269 -79.319796          14   1
# 3     Queen St E / Woodward Ave  43.665269 -79.319796          14   1
# 4     Queen St E / Woodward Ave  43.665269 -79.319796          14   1
# ..                          ...        ...        ...         ...  ..
# 995  Ossington Ave / College St  43.654491 -79.422634           2  50
# 996  Ossington Ave / College St  43.654491 -79.422634           2  50
# 997  Ossington Ave / College St  43.654491 -79.422634           2  50
# 998  Ossington Ave / College St  43.654491 -79.422634           2  50
# 999  Ossington Ave / College St  43.654491 -79.422634           2  50
#
#                        place_name  rating          place_address  result_ID
# 0                         O Sushi     4.0       6 Coxwell Avenue          1
# 1                       Lake Inez     4.5  1471 Gerrard Street E          2
# 2             The Burger's Priest     3.5    1636 Queen Street E          3
# 3                        Jaclyn's     4.5    1588 Queen Street E          4
# 4                Burrito Bandidos     3.5    1614 Queen Street E          5
# ..                            ...     ...                    ...        ...
# 995               The Night Baker     4.0     825 College Street        996
# 996  The Daily Dumpling Wonton Co     4.0         792 College St        997
# 997                     Taverniti     4.0     591 College Street        998
# 998              La Bella Managua     4.5     872 Bloor Street W        999
# 999     Imanishi Japanese Kitchen     4.0   1330 Dundas Street W       1000
#
# [1000 rows x 9 columns]

# %%
#Converting table into csv file
merged_tables.to_csv('merged_tables.csv', index=False)
